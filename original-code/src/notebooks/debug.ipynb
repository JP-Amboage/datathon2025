# %%
from src.base_data import ClientData, SPLIT_DATA_SPLIT1_DIR, load_split_data

# %%
train_data, val_data, test_data = load_split_data(SPLIT_DATA_SPLIT1_DIR)
# Out:
# Loaded 8000 training paths, 1000 validation paths, and 1000 test paths.

# %%
longest_field = ''
longest_field_key = ''
longest_field_len = 0

# explore the dicts of dicts, and get the longest string fields
for cd in train_data:
    # cd is a dataclass: get is as dict
    for key, val in cd.__dict__.items():
        if isinstance(val, dict):
            for k, v in val.items():
                if isinstance(v, str) and len(v) > longest_field_len:
                    longest_field = v
                    longest_field_key = k
                    longest_field_len = len(v)
        elif isinstance(val, str) and len(val) > longest_field_len:
            longest_field = val
            longest_field_key = key
            longest_field_len = len(val)

print(f'Longest field: {longest_field}\nWith length {longest_field_len}\nKey: {longest_field_key}')
# Out:
# Longest field: Having worked for over 22 years, Krol Van den Berg Jansen brings a wealth of experience and expertise to his current role. He is known for his strategic thinking and ability to drive results.
# Krol Van den Berg Jansen's first role was as a Property Manager at CBRE Global Investors Nederland B.V., where he worked diligently from 2003 to 2008 to establish a strong reputation.
# After gaining experience, he took on the role of Developer at Bouwinvest REIM B.V. in 2008, further expanding his skill set.
# In 2014, he joined CBRE Global Investors Nederland B.V. as a Construction Company Owner, taking on new challenges and responsibilities that helped him grow both personally and professionally.
# He appointment as a Real Estate Investment Trust (REIT) CEO at Unibail-Rodamco-Westfield Nederland B.V. in 2020 marked a significant milestone in his career, as he took on increasingly complex challenges and delivered exceptional results.
# He has been a Landlord at Unibail-Rodamco-Westfield Nederland B.V. since 2024, consistently demonstrating his ability to adapt, innovate, and thrive in an ever-changing environment.
# With length 1113
# Key: Occupation History

# %%
len(longest_field.split())
# Out:
# 172

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("roberta-large-mnli")
# model = AutoModelForSequenceClassification.from_pretrained("roberta-large-mnli")

ret = tokenizer(longest_field, return_tensors='pt', padding=True)
type(ret)
# Out:
# transformers.tokenization_utils_base.BatchEncoding

# %%
ret['input_ids'].shape
# Out:
# torch.Size([1, 252])

# %%
ex = train_data[0]
ex.client_description
# Out:
# {'Summary Note': "Margaux Juliette Dubois and the RM met at a networking event in Paris. They quickly realized they had complementary skills and decided to collaborate on several projects.\nWith a career spanning nearly 37 years, Margaux Juliette Dubois has established herself as a key player in the industry.\nAttracted by Julius Baer's reputation for excellence, she chose to join for the bespoke financial solutions offered.\n",
#  'Family Background': 'Margaux Juliette Dubois and Renault tied the knot in 1996. Together they have 3 kids called Capucine, Laurène and Lambert.',
#  'Education Background': 'In 1982, Margaux graduated from Lycée Victor Hugo with a secondary school diploma.\nShe then attended University of Montpellier, which she graduated in 1986.\nMargaux earned her additionally degree from IUT de Strasbourg in 1992.\n',
#  'Occupation History': "Margaux Juliette Dubois is a 61 year old and comes from France.\nMargaux Juliette Dubois's first role was as a Aerospace Engineer at Safran S.A., where she worked diligently from 1988 to 1991 to establish a strong reputation.\nAt Airbus S.A.S., she held the position of Program Manager from 1993 to 1995, making significant contributions to the organization.\nShe spent 3 years working as a Director of Operations at Safran S.A., refining her expertise and building a strong network.\nAfter 11 years of dedication, she assumed the role of VP of Business Development at Safran S.A. in 2000, spearheading high-profile projects and mentoring junior colleagues.\n",
#  'Wealth Summary': 'During her work, she focused on financial growth, making diverse investments and ultimately saving 1230000 EUR.\nShe has house located in Bordeaux, worth 1422000 EUR.\n\nShe purchased condo in Nantes, where she spends her holidays. It is valued at 1690000 EUR.\nMoreover, she has invested in additional property in Toulouse, giving possiblity for generating additional income. The flat is valued at 1540000 EUR.\n\nShe does not have any inheritances.',
#  'Client Summary': 'The RM knows the client very well and is a good friend of the entire family.\n'}

# %%
def get_education(client_data: ClientData) -> str:
    description = client_data.client_description
    profile = client_data.client_profile

    # a. secondary school
    secondary_school = profile.get('secondary_school', {})
    school_name = secondary_school.get('name', 'N/A')
    grad_year = secondary_school.get('graduation_year', 'N/A')
    secondary_school_flat = f'Secondary education at {school_name} graduated in {grad_year}.'

    # b. higher education
    higher_edu = profile.get('higher_education', [])
    higher_edu_flat = ''
    for i, he in enumerate(higher_edu):
        uni_name = he.get('university', 'N/A')
        grad_year = he.get('graduation_year', 'N/A')
        if i > 0:
            higher_edu_flat += ' '
        higher_edu_flat += f'Higher education at {uni_name} graduated in {grad_year}.'

    # description
    description_edu = description.get('Education Background', '').strip()

    # total education
    return f"{secondary_school_flat} {higher_edu_flat} Description says: {description_edu}"

# %%
def get_employment(client_data: ClientData) -> str:
    profile = client_data.client_profile
    description = client_data.client_description

    # a. current employment
    employment = profile.get('employment_history', [])
    if not employment:
        employment_flat = "No employment history recorded."
    else:
        jobs = []
        for job in employment:
            start = job.get('start_year', 'N/A')
            end = job.get('end_year', 'present')
            company = job.get('company', 'N/A')
            position = job.get('position', 'N/A')
            salary = job.get('salary', 'N/A')
            jobs.append(f"Worked at {company} as {position} from {start} to {end}, earning {salary}.")
        employment_flat = ' '.join(jobs)

    # description employment
    description_emp = description.get("Occupation History", '').strip()

    return f"{employment_flat} Description says: {description_emp}"

# %%
def get_inheritance_profile(client_data: ClientData) -> str:
    profile = client_data.client_profile
    description = client_data.client_description

    aum = profile.get("aum", {})
    inheritance_amt = aum.get("inheritance", "N/A")

    inheritance_details = profile.get("inheritance_details", {})
    inh_year = inheritance_details.get("inheritance year", "N/A")
    inh_relation = inheritance_details.get("relationship", "N/A")
    inh_profession = inheritance_details.get("profession", "N/A")

    description_wealth = description.get("Wealth Summary", "").strip()

    return (
        f"Client inherited {inheritance_amt} DKK in {inh_year} from their {inh_relation}, "
        f"who was a {inh_profession}. Description says: {description_wealth}"
    )

# %%
def get_wealth_profile(client_data: ClientData) -> str:
    profile = client_data.client_profile
    description = client_data.client_description

    aum = profile.get("aum", {})
    savings = aum.get("savings", "N/A")
    real_estate_total = aum.get("real_estate_value", "N/A")

    real_estate_details = profile.get("real_estate_details", [])
    real_estate_flat = ""
    if real_estate_details:
        real_estate_parts = []
        for prop in real_estate_details:
            value = prop.get("property value", "N/A")
            ptype = prop.get("property type", "N/A")
            loc = prop.get("property location", "N/A")
            real_estate_parts.append(f"{ptype} in {loc} valued at {value}")
        real_estate_flat = " Properties include: " + "; ".join(real_estate_parts) + "."

    description_wealth = description.get("Wealth Summary", "").strip()

    return (
        f"Client has savings of {savings} DKK and total real estate value of {real_estate_total} DKK."
        f"{real_estate_flat} Description says: {description_wealth}"
    )

# %%
def get_investment_profile(client_data: ClientData) -> str:
    profile = client_data.client_profile
    description = client_data.client_description

    # a. investment risk profile
    risk = profile.get('investment_risk_profile', 'N/A')
    horizon = profile.get('investment_horizon', 'N/A')
    experience = profile.get('investment_experience', 'N/A')
    mandate = profile.get('type_of_mandate', 'N/A')
    markets = profile.get('preferred_markets', [])
    # flatten the markets list
    markets_flat = ', '.join(markets) if markets else 'N/A'

    # description investment
    description_investment = description.get("Client Summary", "").strip()

    return (f"Risk profile: {risk}. Horizon: {horizon}. Experience: {experience}. Mandate: {mandate}. Preferred markets: {markets_flat}. "
            f"Description says: {description_investment}")

# %%
def get_summary_note_profile(client_data: ClientData) -> str:
    profile = client_data.client_profile
    passport = client_data.passport
    description = client_data.client_description

    summary = description.get("Summary Note", "").strip()

    # Extract key facts to compare against structured fields
    birth_date = profile.get("birth_date", "N/A")
    country = profile.get("country_of_domicile", "N/A")
    nationality = profile.get("nationality", "N/A")
    name = profile.get("name", "N/A")

    passport_country = passport.get("country", "N/A")

    return (
        f"Summary note says: {summary} "
        f"Profile says: Name: {name}. Birth date: {birth_date}. "
        f"Domicile: {country}. Nationality: {nationality}. Passport country: {passport_country}."
    )

# %%
def get_family_background_profile(client_data: ClientData) -> str:
    profile = client_data.client_profile
    description = client_data.client_description

    family_bg = description.get("Family Background", "").strip()
    marital_status = profile.get("marital_status", "N/A")

    return (
        f"Family background says: {family_bg} "
        f"Profile marital status: {marital_status}."
    )

# %%
def flatten_fields(client_data: ClientData) -> list[str]:
    flattened = []

    # 1. Education
    flattened.append(get_education(client_data))

    # 2. Employment
    flattened.append(get_employment(client_data))

    # 3. Inheritance
    flattened.append(get_inheritance_profile(client_data))

    # 4. Wealth
    flattened.append(get_wealth_profile(client_data))

    # 5. Investment profile
    flattened.append(get_investment_profile(client_data))

    # 6. Summary note analysis
    flattened.append(get_summary_note_profile(client_data))

    # 7. Family background analysis
    flattened.append(get_family_background_profile(client_data))

    return flattened

# %%
fields = flatten_fields(train_data[0])
fields
# Out:
# ['Secondary education at Lycée Victor Hugo graduated in 1982. Higher education at University of Montpellier graduated in 1986. Higher education at IUT de Strasbourg graduated in 1992. Description says: In 1982, Margaux graduated from Lycée Victor Hugo with a secondary school diploma.\nShe then attended University of Montpellier, which she graduated in 1986.\nMargaux earned her additionally degree from IUT de Strasbourg in 1992.',
#  "Worked at Safran S.A. as Aerospace Engineer from 1988 to 1991, earning 33000. Worked at Airbus S.A.S. as Program Manager from 1993 to 1995, earning 47000. Worked at Safran S.A. as Director of Operations from 1996 to 1999, earning 67000. Worked at Safran S.A. as VP of Business Development from 2000 to 2024, earning 711000. Description says: Margaux Juliette Dubois is a 61 year old and comes from France.\nMargaux Juliette Dubois's first role was as a Aerospace Engineer at Safran S.A., where she worked diligently from 1988 to 1991 to establish a strong reputation.\nAt Airbus S.A.S., she held the position of Program Manager from 1993 to 1995, making significant contributions to the organization.\nShe spent 3 years working as a Director of Operations at Safran S.A., refining her expertise and building a strong network.\nAfter 11 years of dedication, she assumed the role of VP of Business Development at Safran S.A. in 2000, spearheading high-profile projects and mentoring junior colleagues.",
#  'Client inherited 0 DKK in N/A from their N/A, who was a N/A. Description says: During her work, she focused on financial growth, making diverse investments and ultimately saving 1230000 EUR.\nShe has house located in Bordeaux, worth 1422000 EUR.\n\nShe purchased condo in Nantes, where she spends her holidays. It is valued at 1690000 EUR.\nMoreover, she has invested in additional property in Toulouse, giving possiblity for generating additional income. The flat is valued at 1540000 EUR.\n\nShe does not have any inheritances.',
#  'Client has savings of 1230000 DKK and total real estate value of 4652000 DKK. Properties include: house in Bordeaux valued at 1422000; condo in Nantes valued at 1690000; flat in Toulouse valued at 1540000. Description says: During her work, she focused on financial growth, making diverse investments and ultimately saving 1230000 EUR.\nShe has house located in Bordeaux, worth 1422000 EUR.\n\nShe purchased condo in Nantes, where she spends her holidays. It is valued at 1690000 EUR.\nMoreover, she has invested in additional property in Toulouse, giving possiblity for generating additional income. The flat is valued at 1540000 EUR.\n\nShe does not have any inheritances.',
#  'Risk profile: Low. Horizon: Medium. Experience: Experienced. Mandate: Advisory. Preferred markets: France. Description says: The RM knows the client very well and is a good friend of the entire family.',
#  "Summary note says: Margaux Juliette Dubois and the RM met at a networking event in Paris. They quickly realized they had complementary skills and decided to collaborate on several projects.\nWith a career spanning nearly 37 years, Margaux Juliette Dubois has established herself as a key player in the industry.\nAttracted by Julius Baer's reputation for excellence, she chose to join for the bespoke financial solutions offered. Profile says: Name: Margaux Juliette Dubois. Birth date: 1964-01-07. Domicile: France. Nationality: French. Passport country: France.",
#  'Family background says: Margaux Juliette Dubois and Renault tied the knot in 1996. Together they have 3 kids called Capucine, Laurène and Lambert. Profile marital status: married.']

# %%
# run the tokenizer in all the fields to see how long they are
ret = tokenizer(fields, return_tensors='pt', padding=True)
print(f'{ret["input_ids"].shape = }\n\n')

for f in fields:
    ret = tokenizer(f, return_tensors='pt', padding=True)
    print(f'{ret["input_ids"].shape = }')
# Out:
# ret["input_ids"].shape = torch.Size([7, 239])
#
#
# ret["input_ids"].shape = torch.Size([1, 92])
# ret["input_ids"].shape = torch.Size([1, 239])
# ret["input_ids"].shape = torch.Size([1, 128])
# ret["input_ids"].shape = torch.Size([1, 158])
# ret["input_ids"].shape = torch.Size([1, 47])
# ret["input_ids"].shape = torch.Size([1, 126])
# ret["input_ids"].shape = torch.Size([1, 42])

# %%
all_maxlen = 0
for i, cd in enumerate(train_data):
    fields = flatten_fields(cd)
    maxlen = 0
    tokens = tokenizer(fields, return_tensors='pt', padding=True)
    maxlen = max(maxlen, tokens['input_ids'].shape[1])
    print(f'Maxlen for example {i+1:5}: {maxlen}')
    all_maxlen = max(all_maxlen, maxlen)

print(f'All maxlen: {all_maxlen}')
# Out:
# Maxlen for example     1: 239
# Maxlen for example     2: 155
# Maxlen for example     3: 153
# Maxlen for example     4: 138
# Maxlen for example     5: 296
# Maxlen for example     6: 138
# Maxlen for example     7: 345
# Maxlen for example     8: 126
# Maxlen for example     9: 313
# Maxlen for example    10: 143
# Maxlen for example    11: 138
# Maxlen for example    12: 187
# Maxlen for example    13: 121
# Maxlen for example    14: 144
# Maxlen for example    15: 206
# Maxlen for example    16: 138
# Maxlen for example    17: 130
# Maxlen for example    18: 199
# Maxlen for example    19: 136
# Maxlen for example    20: 205
# Maxlen for example    21: 136
# Maxlen for example    22: 169
# Maxlen for example    23: 131
# Maxlen for example    24: 233
# Maxlen for example    25: 133
# Maxlen for example    26: 129
# Maxlen for example    27: 254
# Maxlen for example    28: 150
# Maxlen for example    29: 176
# Maxlen for example    30: 221
# Maxlen for example    31: 176
# Maxlen for example    32: 209
# Maxlen for example    33: 169
# Maxlen for example    34: 149
# Maxlen for example    35: 297
# Maxlen for example    36: 170
# Maxlen for example    37: 181
# Maxlen for example    38: 126
# Maxlen for example    39: 168
# Maxlen for example    40: 134
# Maxlen for example    41: 122
# Maxlen for example    42: 310
# Maxlen for example    43: 337
# Maxlen for example    44: 146
# Maxlen for example    45: 137
# Maxlen for example    46: 132
# Maxlen for example    47: 210
# Maxlen for example    48: 128
# Maxlen for example    49: 125
# Maxlen for example    50: 130
# Maxlen for example    51: 287
# Maxlen for example    52: 336
# Maxlen for example    53: 186
# Maxlen for example    54: 230
# Maxlen for example    55: 233
# Maxlen for example    56: 234
# Maxlen for example    57: 189
# Maxlen for example    58: 297
# Maxlen for example    59: 123
# Maxlen for example    60: 138
# Maxlen for example    61: 160
# Maxlen for example    62: 144
# Maxlen for example    63: 119
# Maxlen for example    64: 164
# Maxlen for example    65: 328
# Maxlen for example    66: 129
# Maxlen for example    67: 124
# Maxlen for example    68: 139
# Maxlen for example    69: 122
# Maxlen for example    70: 151
# Maxlen for example    71: 205
# Maxlen for example    72: 183
# Maxlen for example    73: 232
# Maxlen for example    74: 118
# Maxlen for example    75: 132
# Maxlen for example    76: 133
# Maxlen for example    77: 271
# Maxlen for example    78: 135
# Maxlen for example    79: 157
# Maxlen for example    80: 180
# Maxlen for example    81: 187
# Maxlen for example    82: 191
# Maxlen for example    83: 258
# Maxlen for example    84: 197
# Maxlen for example    85: 150
# Maxlen for example    86: 272
# Maxlen for example    87: 206
# Maxlen for example    88: 219
# Maxlen for example    89: 134
# Maxlen for example    90: 230
# Maxlen for example    91: 268
# Maxlen for example    92: 262
# Maxlen for example    93: 325
# Maxlen for example    94: 172
# Maxlen for example    95: 197
# Maxlen for example    96: 182
# Maxlen for example    97: 143
# Maxlen for example    98: 146
# Maxlen for example    99: 181
# Maxlen for example   100: 209
# Maxlen for example   101: 147
# Maxlen for example   102: 140
# Maxlen for example   103: 239
# Maxlen for example   104: 178
# Maxlen for example   105: 139
# Maxlen for example   106: 147
# Maxlen for example   107: 121
# Maxlen for example   108: 215
# Maxlen for example   109: 235
# Maxlen for example   110: 121
# Maxlen for example   111: 127
# Maxlen for example   112: 336
# Maxlen for example   113: 190
# Maxlen for example   114: 207
# Maxlen for example   115: 305
# Maxlen for example   116: 116
# Maxlen for example   117: 144
# Maxlen for example   118: 199
# Maxlen for example   119: 186
# Maxlen for example   120: 216
# Maxlen for example   121: 141
# Maxlen for example   122: 131
# Maxlen for example   123: 135
# Maxlen for example   124: 184
# Maxlen for example   125: 238
# Maxlen for example   126: 262
# Maxlen for example   127: 174
# Maxlen for example   128: 200
# Maxlen for example   129: 149
# Maxlen for example   130: 244
# Maxlen for example   131: 295
# Maxlen for example   132: 119
# Maxlen for example   133: 168
# Maxlen for example   134: 321
# Maxlen for example   135: 201
# Maxlen for example   136: 126
# Maxlen for example   137: 166
# Maxlen for example   138: 283
# Maxlen for example   139: 300
# Maxlen for example   140: 141
# Maxlen for example   141: 112
# Maxlen for example   142: 113
# Maxlen for example   143: 270
# Maxlen for example   144: 152
# Maxlen for example   145: 146
# Maxlen for example   146: 112
# Maxlen for example   147: 123
# Maxlen for example   148: 276
# Maxlen for example   149: 260
# Maxlen for example   150: 215
# Maxlen for example   151: 175
# Maxlen for example   152: 195
# Maxlen for example   153: 298
# Maxlen for example   154: 119
# Maxlen for example   155: 285
# Maxlen for example   156: 159
# Maxlen for example   157: 268
# Maxlen for example   158: 115
# Maxlen for example   159: 182
# Maxlen for example   160: 286
# Maxlen for example   161: 216
# Maxlen for example   162: 126
# Maxlen for example   163: 161
# Maxlen for example   164: 249
# Maxlen for example   165: 229
# Maxlen for example   166: 121
# Maxlen for example   167: 194
# Maxlen for example   168: 117
# Maxlen for example   169: 126
# Maxlen for example   170: 189
# Maxlen for example   171: 252
# Maxlen for example   172: 115
# Maxlen for example   173: 318
# Maxlen for example   174: 126
# Maxlen for example   175: 299
# Maxlen for example   176: 146
# Maxlen for example   177: 177
# Maxlen for example   178: 245
# Maxlen for example   179: 126
# Maxlen for example   180: 145
# Maxlen for example   181: 323
# Maxlen for example   182: 156
# Maxlen for example   183: 123
# Maxlen for example   184: 132
# Maxlen for example   185: 152
# Maxlen for example   186: 186
# Maxlen for example   187: 150
# Maxlen for example   188: 189
# Maxlen for example   189: 121
# Maxlen for example   190: 213
# Maxlen for example   191: 136
# Maxlen for example   192: 168
# Maxlen for example   193: 209
# Maxlen for example   194: 150
# Maxlen for example   195: 112
# Maxlen for example   196: 145
# Maxlen for example   197: 152
# Maxlen for example   198: 130
# Maxlen for example   199: 165
# Maxlen for example   200: 119
# Maxlen for example   201: 251
# Maxlen for example   202: 304
# Maxlen for example   203: 182
# Maxlen for example   204: 185
# Maxlen for example   205: 182
# Maxlen for example   206: 196
# Maxlen for example   207: 127
# Maxlen for example   208: 310
# Maxlen for example   209: 129
# Maxlen for example   210: 149
# Maxlen for example   211: 149
# Maxlen for example   212: 235
# Maxlen for example   213: 170
# Maxlen for example   214: 173
# Maxlen for example   215: 114
# Maxlen for example   216: 337
# Maxlen for example   217: 157
# Maxlen for example   218: 189
# Maxlen for example   219: 128
# Maxlen for example   220: 202
# Maxlen for example   221: 130
# Maxlen for example   222: 186
# Maxlen for example   223: 176
# Maxlen for example   224: 218
# Maxlen for example   225: 124
# Maxlen for example   226: 217
# Maxlen for example   227: 283
# Maxlen for example   228: 174
# Maxlen for example   229: 157
# Maxlen for example   230: 207
# Maxlen for example   231: 266
# Maxlen for example   232: 130
# Maxlen for example   233: 124
# Maxlen for example   234: 119
# Maxlen for example   235: 317
# Maxlen for example   236: 350
# Maxlen for example   237: 248
# Maxlen for example   238: 164
# Maxlen for example   239: 327
# Maxlen for example   240: 205
# Maxlen for example   241: 138
# Maxlen for example   242: 225
# Maxlen for example   243: 233
# Maxlen for example   244: 169
# Maxlen for example   245: 120
# Maxlen for example   246: 134
# Maxlen for example   247: 136
# Maxlen for example   248: 280
# Maxlen for example   249: 287
# Maxlen for example   250: 126
# Maxlen for example   251: 127
# Maxlen for example   252: 133
# Maxlen for example   253: 197
# Maxlen for example   254: 138
# Maxlen for example   255: 331
# Maxlen for example   256: 160
# Maxlen for example   257: 174
# Maxlen for example   258: 163
# Maxlen for example   259: 240
# Maxlen for example   260: 129
# Maxlen for example   261: 130
# Maxlen for example   262: 258
# Maxlen for example   263: 176
# Maxlen for example   264: 140
# Maxlen for example   265: 363
# Maxlen for example   266: 141
# Maxlen for example   267: 128
# Maxlen for example   268: 215
# Maxlen for example   269: 117
# Maxlen for example   270: 252
# Maxlen for example   271: 157
# Maxlen for example   272: 113
# Maxlen for example   273: 133
# Maxlen for example   274: 179
# Maxlen for example   275: 309
# Maxlen for example   276: 147
# Maxlen for example   277: 113
# Maxlen for example   278: 217
# Maxlen for example   279: 119
# Maxlen for example   280: 210
# Maxlen for example   281: 136
# Maxlen for example   282: 123
# Maxlen for example   283: 144
# Maxlen for example   284: 177
# Maxlen for example   285: 184
# Maxlen for example   286: 189
# Maxlen for example   287: 253
# Maxlen for example   288: 270
# Maxlen for example   289: 182
# Maxlen for example   290: 145
# Maxlen for example   291: 121
# Maxlen for example   292: 187
# Maxlen for example   293: 239
# Maxlen for example   294: 278
# Maxlen for example   295: 148
# Maxlen for example   296: 232
# Maxlen for example   297: 183
# Maxlen for example   298: 131
# Maxlen for example   299: 142
# Maxlen for example   300: 191
# Maxlen for example   301: 135
# Maxlen for example   302: 192
# Maxlen for example   303: 181
# Maxlen for example   304: 198
# Maxlen for example   305: 229
# Maxlen for example   306: 188
# Maxlen for example   307: 184
# Maxlen for example   308: 120
# Maxlen for example   309: 187
# Maxlen for example   310: 166
# Maxlen for example   311: 238
# Maxlen for example   312: 158
# Maxlen for example   313: 181
# Maxlen for example   314: 218
# Maxlen for example   315: 277
# Maxlen for example   316: 182
# Maxlen for example   317: 355
# Maxlen for example   318: 146
# Maxlen for example   319: 194
# Maxlen for example   320: 131
# Maxlen for example   321: 170
# Maxlen for example   322: 181
# Maxlen for example   323: 266
# Maxlen for example   324: 137
# Maxlen for example   325: 213
# Maxlen for example   326: 234
# Maxlen for example   327: 127
# Maxlen for example   328: 298
# Maxlen for example   329: 130
# Maxlen for example   330: 137
# Maxlen for example   331: 184
# Maxlen for example   332: 147
# Maxlen for example   333: 259
# Maxlen for example   334: 170
# Maxlen for example   335: 180
# Maxlen for example   336: 161
# Maxlen for example   337: 184
# Maxlen for example   338: 125
# Maxlen for example   339: 199
# Maxlen for example   340: 134
# Maxlen for example   341: 117
# Maxlen for example   342: 244
# Maxlen for example   343: 154
# Maxlen for example   344: 119
# Maxlen for example   345: 174
# Maxlen for example   346: 245
# Maxlen for example   347: 152
# Maxlen for example   348: 190
# Maxlen for example   349: 269
# Maxlen for example   350: 124
# Maxlen for example   351: 209
# Maxlen for example   352: 143
# Maxlen for example   353: 148
# Maxlen for example   354: 241
# Maxlen for example   355: 321
# Maxlen for example   356: 151
# Maxlen for example   357: 323
# Maxlen for example   358: 132
# Maxlen for example   359: 146
# Maxlen for example   360: 141
# Maxlen for example   361: 154
# Maxlen for example   362: 154
# Maxlen for example   363: 239
# Maxlen for example   364: 223
# Maxlen for example   365: 160
# Maxlen for example   366: 134
# Maxlen for example   367: 231
# Maxlen for example   368: 182
# Maxlen for example   369: 189
# Maxlen for example   370: 207
# Maxlen for example   371: 125
# Maxlen for example   372: 125
# Maxlen for example   373: 160
# Maxlen for example   374: 155
# Maxlen for example   375: 321
# Maxlen for example   376: 199
# Maxlen for example   377: 194
# Maxlen for example   378: 126
# Maxlen for example   379: 302
# Maxlen for example   380: 181
# Maxlen for example   381: 143
# Maxlen for example   382: 154
# Maxlen for example   383: 120
# Maxlen for example   384: 123
# Maxlen for example   385: 114
# Maxlen for example   386: 175
# Maxlen for example   387: 171
# Maxlen for example   388: 193
# Maxlen for example   389: 163
# Maxlen for example   390: 118
# Maxlen for example   391: 192
# Maxlen for example   392: 232
# Maxlen for example   393: 298
# Maxlen for example   394: 206
# Maxlen for example   395: 254
# Maxlen for example   396: 116
# Maxlen for example   397: 188
# Maxlen for example   398: 151
# Maxlen for example   399: 247
# Maxlen for example   400: 145
# Maxlen for example   401: 132
# Maxlen for example   402: 137
# Maxlen for example   403: 300
# Maxlen for example   404: 144
# Maxlen for example   405: 188
# Maxlen for example   406: 122
# Maxlen for example   407: 179
# Maxlen for example   408: 162
# Maxlen for example   409: 144
# Maxlen for example   410: 122
# Maxlen for example   411: 168
# Maxlen for example   412: 140
# Maxlen for example   413: 121
# Maxlen for example   414: 355
# Maxlen for example   415: 121
# Maxlen for example   416: 147
# Maxlen for example   417: 206
# Maxlen for example   418: 256
# Maxlen for example   419: 279
# Maxlen for example   420: 306
# Maxlen for example   421: 337
# Maxlen for example   422: 143
# Maxlen for example   423: 142
# Maxlen for example   424: 187
# Maxlen for example   425: 118
# Maxlen for example   426: 205
# Maxlen for example   427: 189
# Maxlen for example   428: 138
# Maxlen for example   429: 260
# Maxlen for example   430: 142
# Maxlen for example   431: 237
# Maxlen for example   432: 127
# Maxlen for example   433: 183
# Maxlen for example   434: 265
# Maxlen for example   435: 198
# Maxlen for example   436: 128
# Maxlen for example   437: 169
# Maxlen for example   438: 167
# Maxlen for example   439: 153
# Maxlen for example   440: 187
# Maxlen for example   441: 119
# Maxlen for example   442: 135
# Maxlen for example   443: 123
# Maxlen for example   444: 184
# Maxlen for example   445: 254
# Maxlen for example   446: 165
# Maxlen for example   447: 314
# Maxlen for example   448: 139
# Maxlen for example   449: 126
# Maxlen for example   450: 346
# Maxlen for example   451: 127
# Maxlen for example   452: 133
# Maxlen for example   453: 177
# Maxlen for example   454: 279
# Maxlen for example   455: 291
# Maxlen for example   456: 155
# Maxlen for example   457: 193
# Maxlen for example   458: 131
# Maxlen for example   459: 148
# Maxlen for example   460: 129
# Maxlen for example   461: 245
# Maxlen for example   462: 212
# Maxlen for example   463: 132
# Maxlen for example   464: 221
# Maxlen for example   465: 127
# Maxlen for example   466: 144
# Maxlen for example   467: 119
# Maxlen for example   468: 191
# Maxlen for example   469: 287
# Maxlen for example   470: 284
# Maxlen for example   471: 120
# Maxlen for example   472: 186
# Maxlen for example   473: 236
# Maxlen for example   474: 193
# Maxlen for example   475: 164
# Maxlen for example   476: 121
# Maxlen for example   477: 295
# Maxlen for example   478: 150
# Maxlen for example   479: 178
# Maxlen for example   480: 143
# Maxlen for example   481: 246
# Maxlen for example   482: 241
# Maxlen for example   483: 115
# Maxlen for example   484: 246
# Maxlen for example   485: 216
# Maxlen for example   486: 182
# Maxlen for example   487: 121
# Maxlen for example   488: 274
# Maxlen for example   489: 174
# Maxlen for example   490: 210
# Maxlen for example   491: 192
# Maxlen for example   492: 237
# Maxlen for example   493: 123
# Maxlen for example   494: 144
# Maxlen for example   495: 124
# Maxlen for example   496: 209
# Maxlen for example   497: 116
# Maxlen for example   498: 184
# Maxlen for example   499: 308
# Maxlen for example   500: 175
# Maxlen for example   501: 306
# Maxlen for example   502: 198
# Maxlen for example   503: 196
# Maxlen for example   504: 282
# Maxlen for example   505: 139
# Maxlen for example   506: 171
# Maxlen for example   507: 178
# Maxlen for example   508: 166
# Maxlen for example   509: 318
# Maxlen for example   510: 124
# Maxlen for example   511: 127
# Maxlen for example   512: 207
# Maxlen for example   513: 118
# Maxlen for example   514: 157
# Maxlen for example   515: 146
# Maxlen for example   516: 178
# Maxlen for example   517: 132
# Maxlen for example   518: 183
# Maxlen for example   519: 226
# Maxlen for example   520: 299
# Maxlen for example   521: 206
# Maxlen for example   522: 200
# Maxlen for example   523: 195
# Maxlen for example   524: 222
# Maxlen for example   525: 227
# Maxlen for example   526: 141
# Maxlen for example   527: 182
# Maxlen for example   528: 125
# Maxlen for example   529: 273
# Maxlen for example   530: 131
# Maxlen for example   531: 158
# Maxlen for example   532: 113
# Maxlen for example   533: 274
# Maxlen for example   534: 314
# Maxlen for example   535: 190
# Maxlen for example   536: 120
# Maxlen for example   537: 146
# Maxlen for example   538: 120
# Maxlen for example   539: 201
# Maxlen for example   540: 143
# Maxlen for example   541: 124
# Maxlen for example   542: 271
# Maxlen for example   543: 110
# Maxlen for example   544: 116
# Maxlen for example   545: 189
# Maxlen for example   546: 125
# Maxlen for example   547: 134
# Maxlen for example   548: 299
# Maxlen for example   549: 261
# Maxlen for example   550: 126
# Maxlen for example   551: 188
# Maxlen for example   552: 134
# Maxlen for example   553: 211
# Maxlen for example   554: 263
# Maxlen for example   555: 135
# Maxlen for example   556: 124
# Maxlen for example   557: 326
# Maxlen for example   558: 369
# Maxlen for example   559: 211
# Maxlen for example   560: 201
# Maxlen for example   561: 247
# Maxlen for example   562: 152
# Maxlen for example   563: 214
# Maxlen for example   564: 124
# Maxlen for example   565: 242
# Maxlen for example   566: 165
# Maxlen for example   567: 130
# Maxlen for example   568: 286
# Maxlen for example   569: 218
# Maxlen for example   570: 186
# Maxlen for example   571: 140
# Maxlen for example   572: 138
# Maxlen for example   573: 165
# Maxlen for example   574: 144
# Maxlen for example   575: 192
# Maxlen for example   576: 246
# Maxlen for example   577: 244
# Maxlen for example   578: 122
# Maxlen for example   579: 242
# Maxlen for example   580: 233
# Maxlen for example   581: 130
# Maxlen for example   582: 220
# Maxlen for example   583: 158
# Maxlen for example   584: 133
# Maxlen for example   585: 167
# Maxlen for example   586: 202
# Maxlen for example   587: 117
# Maxlen for example   588: 222
# Maxlen for example   589: 305
# Maxlen for example   590: 241
# Maxlen for example   591: 276
# Maxlen for example   592: 128
# Maxlen for example   593: 232
# Maxlen for example   594: 312
# Maxlen for example   595: 152
# Maxlen for example   596: 194
# Maxlen for example   597: 158
# Maxlen for example   598: 123
# Maxlen for example   599: 127
# Maxlen for example   600: 122
# Maxlen for example   601: 195
# Maxlen for example   602: 151
# Maxlen for example   603: 120
# Maxlen for example   604: 123
# Maxlen for example   605: 172
# Maxlen for example   606: 138
# Maxlen for example   607: 158
# Maxlen for example   608: 272
# Maxlen for example   609: 129
# Maxlen for example   610: 132
# Maxlen for example   611: 210
# Maxlen for example   612: 128
# Maxlen for example   613: 110
# Maxlen for example   614: 127
# Maxlen for example   615: 126
# Maxlen for example   616: 158
# Maxlen for example   617: 124
# Maxlen for example   618: 128
# Maxlen for example   619: 121
# Maxlen for example   620: 177
# Maxlen for example   621: 217
# Maxlen for example   622: 144
# Maxlen for example   623: 240
# Maxlen for example   624: 170
# Maxlen for example   625: 156
# Maxlen for example   626: 210
# Maxlen for example   627: 216
# Maxlen for example   628: 293
# Maxlen for example   629: 135
# Maxlen for example   630: 120
# Maxlen for example   631: 249
# Maxlen for example   632: 202
# Maxlen for example   633: 309
# Maxlen for example   634: 142
# Maxlen for example   635: 293
# Maxlen for example   636: 130
# Maxlen for example   637: 194
# Maxlen for example   638: 156
# Maxlen for example   639: 145
# Maxlen for example   640: 128
# Maxlen for example   641: 263
# Maxlen for example   642: 173
# Maxlen for example   643: 122
# Maxlen for example   644: 268
# Maxlen for example   645: 264
# Maxlen for example   646: 185
# Maxlen for example   647: 201
# Maxlen for example   648: 142
# Maxlen for example   649: 248
# Maxlen for example   650: 140
# Maxlen for example   651: 114
# Maxlen for example   652: 146
# Maxlen for example   653: 269
# Maxlen for example   654: 180
# Maxlen for example   655: 216
# Maxlen for example   656: 190
# Maxlen for example   657: 218
# Maxlen for example   658: 132
# Maxlen for example   659: 118
# Maxlen for example   660: 313
# Maxlen for example   661: 206
# Maxlen for example   662: 358
# Maxlen for example   663: 142
# Maxlen for example   664: 175
# Maxlen for example   665: 126
# Maxlen for example   666: 225
# Maxlen for example   667: 193
# Maxlen for example   668: 147
# Maxlen for example   669: 142
# Maxlen for example   670: 131
# Maxlen for example   671: 188
# Maxlen for example   672: 165
# Maxlen for example   673: 237
# Maxlen for example   674: 364
# Maxlen for example   675: 234
# Maxlen for example   676: 157
# Maxlen for example   677: 121
# Maxlen for example   678: 308
# Maxlen for example   679: 330
# Maxlen for example   680: 123
# Maxlen for example   681: 270
# Maxlen for example   682: 141
# Maxlen for example   683: 128
# Maxlen for example   684: 289
# Maxlen for example   685: 228
# Maxlen for example   686: 214
# Maxlen for example   687: 118
# Maxlen for example   688: 192
# Maxlen for example   689: 184
# Maxlen for example   690: 127
# Maxlen for example   691: 139
# Maxlen for example   692: 310
# Maxlen for example   693: 292
# Maxlen for example   694: 205
# Maxlen for example   695: 278
# Maxlen for example   696: 130
# Maxlen for example   697: 135
# Maxlen for example   698: 168
# Maxlen for example   699: 148
# Maxlen for example   700: 346
# Maxlen for example   701: 276
# Maxlen for example   702: 265
# Maxlen for example   703: 115
# Maxlen for example   704: 139
# Maxlen for example   705: 200
# Maxlen for example   706: 273
# Maxlen for example   707: 120
# Maxlen for example   708: 125
# Maxlen for example   709: 137
# Maxlen for example   710: 296
# Maxlen for example   711: 178
# Maxlen for example   712: 129
# Maxlen for example   713: 171
# Maxlen for example   714: 190
# Maxlen for example   715: 139
# Maxlen for example   716: 155
# Maxlen for example   717: 320
# Maxlen for example   718: 147
# Maxlen for example   719: 124
# Maxlen for example   720: 127
# Maxlen for example   721: 163
# Maxlen for example   722: 304
# Maxlen for example   723: 119
# Maxlen for example   724: 125
# Maxlen for example   725: 120
# Maxlen for example   726: 125
# Maxlen for example   727: 185
# Maxlen for example   728: 247
# Maxlen for example   729: 235
# Maxlen for example   730: 312
# Maxlen for example   731: 128
# Maxlen for example   732: 158
# Maxlen for example   733: 207
# Maxlen for example   734: 131
# Maxlen for example   735: 214
# Maxlen for example   736: 124
# Maxlen for example   737: 188
# Maxlen for example   738: 144
# Maxlen for example   739: 115
# Maxlen for example   740: 120
# Maxlen for example   741: 117
# Maxlen for example   742: 333
# Maxlen for example   743: 125
# Maxlen for example   744: 210
# Maxlen for example   745: 123
# Maxlen for example   746: 213
# Maxlen for example   747: 132
# Maxlen for example   748: 186
# Maxlen for example   749: 193
# Maxlen for example   750: 197
# Maxlen for example   751: 263
# Maxlen for example   752: 116
# Maxlen for example   753: 129
# Maxlen for example   754: 132
# Maxlen for example   755: 187
# Maxlen for example   756: 224
# Maxlen for example   757: 187
# Maxlen for example   758: 236
# Maxlen for example   759: 125
# Maxlen for example   760: 148
# Maxlen for example   761: 224
# Maxlen for example   762: 142
# Maxlen for example   763: 153
# Maxlen for example   764: 125
# Maxlen for example   765: 343
# Maxlen for example   766: 229
# Maxlen for example   767: 133
# Maxlen for example   768: 129
# Maxlen for example   769: 186
# Maxlen for example   770: 121
# Maxlen for example   771: 122
# Maxlen for example   772: 127
# Maxlen for example   773: 135
# Maxlen for example   774: 120
# Maxlen for example   775: 143
# Maxlen for example   776: 184
# Maxlen for example   777: 277
# Maxlen for example   778: 172
# Maxlen for example   779: 150
# Maxlen for example   780: 127
# Maxlen for example   781: 146
# Maxlen for example   782: 176
# Maxlen for example   783: 119
# Maxlen for example   784: 129
# Maxlen for example   785: 265
# Maxlen for example   786: 191
# Maxlen for example   787: 198
# Maxlen for example   788: 242
# Maxlen for example   789: 117
# Maxlen for example   790: 140
# Maxlen for example   791: 224
# Maxlen for example   792: 212
# Maxlen for example   793: 121
# Maxlen for example   794: 231
# Maxlen for example   795: 184
# Maxlen for example   796: 240
# Maxlen for example   797: 189
# Maxlen for example   798: 201
# Maxlen for example   799: 305
# Maxlen for example   800: 142
# Maxlen for example   801: 143
# Maxlen for example   802: 148
# Maxlen for example   803: 258
# Maxlen for example   804: 121
# Maxlen for example   805: 123
# Maxlen for example   806: 255
# Maxlen for example   807: 150
# Maxlen for example   808: 156
# Maxlen for example   809: 208
# Maxlen for example   810: 211
# Maxlen for example   811: 163
# Maxlen for example   812: 183
# Maxlen for example   813: 130
# Maxlen for example   814: 135
# Maxlen for example   815: 217
# Maxlen for example   816: 179
# Maxlen for example   817: 220
# Maxlen for example   818: 268
# Maxlen for example   819: 340
# Maxlen for example   820: 229
# Maxlen for example   821: 187
# Maxlen for example   822: 259
# Maxlen for example   823: 167
# Maxlen for example   824: 119
# Maxlen for example   825: 142
# Maxlen for example   826: 217
# Maxlen for example   827: 267
# Maxlen for example   828: 252
# Maxlen for example   829: 118
# Maxlen for example   830: 215
# Maxlen for example   831: 119
# Maxlen for example   832: 143
# Maxlen for example   833: 146
# Maxlen for example   834: 280
# Maxlen for example   835: 125
# Maxlen for example   836: 131
# Maxlen for example   837: 144
# Maxlen for example   838: 178
# Maxlen for example   839: 279
# Maxlen for example   840: 175
# Maxlen for example   841: 200
# Maxlen for example   842: 133
# Maxlen for example   843: 120
# Maxlen for example   844: 147
# Maxlen for example   845: 227
# Maxlen for example   846: 124
# Maxlen for example   847: 146
# Maxlen for example   848: 130
# Maxlen for example   849: 133
# Maxlen for example   850: 115
# Maxlen for example   851: 149
# Maxlen for example   852: 257
# Maxlen for example   853: 122
# Maxlen for example   854: 193
# Maxlen for example   855: 146
# Maxlen for example   856: 289
# Maxlen for example   857: 121
# Maxlen for example   858: 213
# Maxlen for example   859: 285
# Maxlen for example   860: 218
# Maxlen for example   861: 274
# Maxlen for example   862: 146
# Maxlen for example   863: 183
# Maxlen for example   864: 165
# Maxlen for example   865: 270
# Maxlen for example   866: 197
# Maxlen for example   867: 185
# Maxlen for example   868: 118
# Maxlen for example   869: 136
# Maxlen for example   870: 136
# Maxlen for example   871: 287
# Maxlen for example   872: 202
# Maxlen for example   873: 127
# Maxlen for example   874: 151
# Maxlen for example   875: 343
# Maxlen for example   876: 190
# Maxlen for example   877: 157
# Maxlen for example   878: 121
# Maxlen for example   879: 135
# Maxlen for example   880: 189
# Maxlen for example   881: 118
# Maxlen for example   882: 201
# Maxlen for example   883: 229
# Maxlen for example   884: 166
# Maxlen for example   885: 153
# Maxlen for example   886: 168
# Maxlen for example   887: 198
# Maxlen for example   888: 112
# Maxlen for example   889: 173
# Maxlen for example   890: 122
# Maxlen for example   891: 190
# Maxlen for example   892: 275
# Maxlen for example   893: 122
# Maxlen for example   894: 199
# Maxlen for example   895: 292
# Maxlen for example   896: 268
# Maxlen for example   897: 140
# Maxlen for example   898: 174
# Maxlen for example   899: 124
# Maxlen for example   900: 227
# Maxlen for example   901: 111
# Maxlen for example   902: 300
# Maxlen for example   903: 258
# Maxlen for example   904: 180
# Maxlen for example   905: 156
# Maxlen for example   906: 305
# Maxlen for example   907: 122
# Maxlen for example   908: 178
# Maxlen for example   909: 143
# Maxlen for example   910: 115
# Maxlen for example   911: 167
# Maxlen for example   912: 173
# Maxlen for example   913: 166
# Maxlen for example   914: 188
# Maxlen for example   915: 178
# Maxlen for example   916: 171
# Maxlen for example   917: 253
# Maxlen for example   918: 118
# Maxlen for example   919: 169
# Maxlen for example   920: 218
# Maxlen for example   921: 136
# Maxlen for example   922: 139
# Maxlen for example   923: 169
# Maxlen for example   924: 233
# Maxlen for example   925: 195
# Maxlen for example   926: 125
# Maxlen for example   927: 202
# Maxlen for example   928: 131
# Maxlen for example   929: 118
# Maxlen for example   930: 115
# Maxlen for example   931: 172
# Maxlen for example   932: 118
# Maxlen for example   933: 182
# Maxlen for example   934: 268
# Maxlen for example   935: 193
# Maxlen for example   936: 145
# Maxlen for example   937: 296
# Maxlen for example   938: 204
# Maxlen for example   939: 172
# Maxlen for example   940: 165
# Maxlen for example   941: 179
# Maxlen for example   942: 221
# Maxlen for example   943: 153
# Maxlen for example   944: 161
# Maxlen for example   945: 133
# Maxlen for example   946: 126
# Maxlen for example   947: 118
# Maxlen for example   948: 139
# Maxlen for example   949: 153
# Maxlen for example   950: 182
# Maxlen for example   951: 151
# Maxlen for example   952: 142
# Maxlen for example   953: 125
# Maxlen for example   954: 129
# Maxlen for example   955: 199
# Maxlen for example   956: 127
# Maxlen for example   957: 165
# Maxlen for example   958: 125
# Maxlen for example   959: 140
# Maxlen for example   960: 136
# Maxlen for example   961: 131
# Maxlen for example   962: 207
# Maxlen for example   963: 131
# Maxlen for example   964: 169
# Maxlen for example   965: 197
# Maxlen for example   966: 293
# Maxlen for example   967: 232
# Maxlen for example   968: 222
# Maxlen for example   969: 142
# Maxlen for example   970: 175
# Maxlen for example   971: 126
# Maxlen for example   972: 117
# Maxlen for example   973: 130
# Maxlen for example   974: 153
# Maxlen for example   975: 128
# Maxlen for example   976: 131
# Maxlen for example   977: 140
# Maxlen for example   978: 148
# Maxlen for example   979: 133
# Maxlen for example   980: 152
# Maxlen for example   981: 187
# Maxlen for example   982: 279
# Maxlen for example   983: 201
# Maxlen for example   984: 275
# Maxlen for example   985: 130
# Maxlen for example   986: 128
# Maxlen for example   987: 185
# Maxlen for example   988: 226
# Maxlen for example   989: 116
# Maxlen for example   990: 206
# Maxlen for example   991: 138
# Maxlen for example   992: 133
# Maxlen for example   993: 189
# Maxlen for example   994: 178
# Maxlen for example   995: 172
# Maxlen for example   996: 199
# Maxlen for example   997: 120
# Maxlen for example   998: 139
# Maxlen for example   999: 149
# Maxlen for example  1000: 156
# Maxlen for example  1001: 292
# Maxlen for example  1002: 136
# Maxlen for example  1003: 160
# Maxlen for example  1004: 185
# Maxlen for example  1005: 177
# Maxlen for example  1006: 141
# Maxlen for example  1007: 192
# Maxlen for example  1008: 132
# Maxlen for example  1009: 177
# Maxlen for example  1010: 121
# Maxlen for example  1011: 203
# Maxlen for example  1012: 214
# Maxlen for example  1013: 144
# Maxlen for example  1014: 155
# Maxlen for example  1015: 274
# Maxlen for example  1016: 143
# Maxlen for example  1017: 190
# Maxlen for example  1018: 178
# Maxlen for example  1019: 209
# Maxlen for example  1020: 153
# Maxlen for example  1021: 137
# Maxlen for example  1022: 254
# Maxlen for example  1023: 191
# Maxlen for example  1024: 125
# Maxlen for example  1025: 222
# Maxlen for example  1026: 209
# Maxlen for example  1027: 184
# Maxlen for example  1028: 280
# Maxlen for example  1029: 197
# Maxlen for example  1030: 243
# Maxlen for example  1031: 184
# Maxlen for example  1032: 194
# Maxlen for example  1033: 115
# Maxlen for example  1034: 141
# Maxlen for example  1035: 123
# Maxlen for example  1036: 117
# Maxlen for example  1037: 132
# Maxlen for example  1038: 122
# Maxlen for example  1039: 147
# Maxlen for example  1040: 243
# Maxlen for example  1041: 177
# Maxlen for example  1042: 129
# Maxlen for example  1043: 127
# Maxlen for example  1044: 187
# Maxlen for example  1045: 170
# Maxlen for example  1046: 188
# Maxlen for example  1047: 172
# Maxlen for example  1048: 316
# Maxlen for example  1049: 118
# Maxlen for example  1050: 176
# Maxlen for example  1051: 140
# Maxlen for example  1052: 330
# Maxlen for example  1053: 165
# Maxlen for example  1054: 176
# Maxlen for example  1055: 118
# Maxlen for example  1056: 275
# Maxlen for example  1057: 155
# Maxlen for example  1058: 238
# Maxlen for example  1059: 119
# Maxlen for example  1060: 148
# Maxlen for example  1061: 177
# Maxlen for example  1062: 116
# Maxlen for example  1063: 173
# Maxlen for example  1064: 166
# Maxlen for example  1065: 184
# Maxlen for example  1066: 131
# Maxlen for example  1067: 123
# Maxlen for example  1068: 255
# Maxlen for example  1069: 238
# Maxlen for example  1070: 315
# Maxlen for example  1071: 184
# Maxlen for example  1072: 122
# Maxlen for example  1073: 235
# Maxlen for example  1074: 123
# Maxlen for example  1075: 343
# Maxlen for example  1076: 144
# Maxlen for example  1077: 123
# Maxlen for example  1078: 195
# Maxlen for example  1079: 192
# Maxlen for example  1080: 211
# Maxlen for example  1081: 152
# Maxlen for example  1082: 164
# Maxlen for example  1083: 289
# Maxlen for example  1084: 244
# Maxlen for example  1085: 164
# Maxlen for example  1086: 296
# Maxlen for example  1087: 156
# Maxlen for example  1088: 158
# Maxlen for example  1089: 194
# Maxlen for example  1090: 182
# Maxlen for example  1091: 184
# Maxlen for example  1092: 128
# Maxlen for example  1093: 186
# Maxlen for example  1094: 174
# Maxlen for example  1095: 141
# Maxlen for example  1096: 119
# Maxlen for example  1097: 156
# Maxlen for example  1098: 219
# Maxlen for example  1099: 113
# Maxlen for example  1100: 161
# Maxlen for example  1101: 186
# Maxlen for example  1102: 263
# Maxlen for example  1103: 320
# Maxlen for example  1104: 245
# Maxlen for example  1105: 202
# Maxlen for example  1106: 121
# Maxlen for example  1107: 299
# Maxlen for example  1108: 241
# Maxlen for example  1109: 250
# Maxlen for example  1110: 137
# Maxlen for example  1111: 173
# Maxlen for example  1112: 178
# Maxlen for example  1113: 190
# Maxlen for example  1114: 239
# Maxlen for example  1115: 124
# Maxlen for example  1116: 117
# Maxlen for example  1117: 130
# Maxlen for example  1118: 126
# Maxlen for example  1119: 361
# Maxlen for example  1120: 134
# Maxlen for example  1121: 315
# Maxlen for example  1122: 156
# Maxlen for example  1123: 176
# Maxlen for example  1124: 289
# Maxlen for example  1125: 171
# Maxlen for example  1126: 167
# Maxlen for example  1127: 166
# Maxlen for example  1128: 113
# Maxlen for example  1129: 141
# Maxlen for example  1130: 121
# Maxlen for example  1131: 139
# Maxlen for example  1132: 160
# Maxlen for example  1133: 144
# Maxlen for example  1134: 119
# Maxlen for example  1135: 136
# Maxlen for example  1136: 136
# Maxlen for example  1137: 138
# Maxlen for example  1138: 172
# Maxlen for example  1139: 165
# Maxlen for example  1140: 323
# Maxlen for example  1141: 246
# Maxlen for example  1142: 200
# Maxlen for example  1143: 245
# Maxlen for example  1144: 183
# Maxlen for example  1145: 251
# Maxlen for example  1146: 185
# Maxlen for example  1147: 152
# Maxlen for example  1148: 122
# Maxlen for example  1149: 259
# Maxlen for example  1150: 187
# Maxlen for example  1151: 202
# Maxlen for example  1152: 199
# Maxlen for example  1153: 140
# Maxlen for example  1154: 167
# Maxlen for example  1155: 245
# Maxlen for example  1156: 165
# Maxlen for example  1157: 136
# Maxlen for example  1158: 131
# Maxlen for example  1159: 152
# Maxlen for example  1160: 150
# Maxlen for example  1161: 153
# Maxlen for example  1162: 123
# Maxlen for example  1163: 222
# Maxlen for example  1164: 125
# Maxlen for example  1165: 122
# Maxlen for example  1166: 140
# Maxlen for example  1167: 120
# Maxlen for example  1168: 185
# Maxlen for example  1169: 119
# Maxlen for example  1170: 200
# Maxlen for example  1171: 137
# Maxlen for example  1172: 113
# Maxlen for example  1173: 314
# Maxlen for example  1174: 277
# Maxlen for example  1175: 125
# Maxlen for example  1176: 129
# Maxlen for example  1177: 161
# Maxlen for example  1178: 304
# Maxlen for example  1179: 241
# Maxlen for example  1180: 212
# Maxlen for example  1181: 219
# Maxlen for example  1182: 283
# Maxlen for example  1183: 181
# Maxlen for example  1184: 197
# Maxlen for example  1185: 138
# Maxlen for example  1186: 198
# Maxlen for example  1187: 189
# Maxlen for example  1188: 171
# Maxlen for example  1189: 121
# Maxlen for example  1190: 205
# Maxlen for example  1191: 126
# Maxlen for example  1192: 300
# Maxlen for example  1193: 156
# Maxlen for example  1194: 157
# Maxlen for example  1195: 149
# Maxlen for example  1196: 164
# Maxlen for example  1197: 150
# Maxlen for example  1198: 166
# Maxlen for example  1199: 124
# Maxlen for example  1200: 159
# Maxlen for example  1201: 207
# Maxlen for example  1202: 148
# Maxlen for example  1203: 139
# Maxlen for example  1204: 125
# Maxlen for example  1205: 129
# Maxlen for example  1206: 226
# Maxlen for example  1207: 185
# Maxlen for example  1208: 209
# Maxlen for example  1209: 311
# Maxlen for example  1210: 174
# Maxlen for example  1211: 179
# Maxlen for example  1212: 118
# Maxlen for example  1213: 130
# Maxlen for example  1214: 290
# Maxlen for example  1215: 190
# Maxlen for example  1216: 140
# Maxlen for example  1217: 170
# Maxlen for example  1218: 119
# Maxlen for example  1219: 171
# Maxlen for example  1220: 297
# Maxlen for example  1221: 188
# Maxlen for example  1222: 111
# Maxlen for example  1223: 172
# Maxlen for example  1224: 120
# Maxlen for example  1225: 144
# Maxlen for example  1226: 224
# Maxlen for example  1227: 218
# Maxlen for example  1228: 261
# Maxlen for example  1229: 121
# Maxlen for example  1230: 127
# Maxlen for example  1231: 126
# Maxlen for example  1232: 201
# Maxlen for example  1233: 142
# Maxlen for example  1234: 314
# Maxlen for example  1235: 232
# Maxlen for example  1236: 273
# Maxlen for example  1237: 275
# Maxlen for example  1238: 177
# Maxlen for example  1239: 219
# Maxlen for example  1240: 241
# Maxlen for example  1241: 136
# Maxlen for example  1242: 224
# Maxlen for example  1243: 133
# Maxlen for example  1244: 115
# Maxlen for example  1245: 224
# Maxlen for example  1246: 147
# Maxlen for example  1247: 142
# Maxlen for example  1248: 114
# Maxlen for example  1249: 305
# Maxlen for example  1250: 200
# Maxlen for example  1251: 199
# Maxlen for example  1252: 132
# Maxlen for example  1253: 214
# Maxlen for example  1254: 208
# Maxlen for example  1255: 175
# Maxlen for example  1256: 123
# Maxlen for example  1257: 162
# Maxlen for example  1258: 131
# Maxlen for example  1259: 140
# Maxlen for example  1260: 245
# Maxlen for example  1261: 188
# Maxlen for example  1262: 115
# Maxlen for example  1263: 199
# Maxlen for example  1264: 322
# Maxlen for example  1265: 115
# Maxlen for example  1266: 159
# Maxlen for example  1267: 213
# Maxlen for example  1268: 119
# Maxlen for example  1269: 151
# Maxlen for example  1270: 118
# Maxlen for example  1271: 118
# Maxlen for example  1272: 122
# Maxlen for example  1273: 279
# Maxlen for example  1274: 125
# Maxlen for example  1275: 122
# Maxlen for example  1276: 286
# Maxlen for example  1277: 187
# Maxlen for example  1278: 183
# Maxlen for example  1279: 149
# Maxlen for example  1280: 175
# Maxlen for example  1281: 121
# Maxlen for example  1282: 236
# Maxlen for example  1283: 135
# Maxlen for example  1284: 144
# Maxlen for example  1285: 300
# Maxlen for example  1286: 129
# Maxlen for example  1287: 185
# Maxlen for example  1288: 163
# Maxlen for example  1289: 134
# Maxlen for example  1290: 183
# Maxlen for example  1291: 206
# Maxlen for example  1292: 128
# Maxlen for example  1293: 300
# Maxlen for example  1294: 193
# Maxlen for example  1295: 136
# Maxlen for example  1296: 133
# Maxlen for example  1297: 261
# Maxlen for example  1298: 127
# Maxlen for example  1299: 157
# Maxlen for example  1300: 213
# Maxlen for example  1301: 309
# Maxlen for example  1302: 140
# Maxlen for example  1303: 222
# Maxlen for example  1304: 116
# Maxlen for example  1305: 144
# Maxlen for example  1306: 206
# Maxlen for example  1307: 303
# Maxlen for example  1308: 277
# Maxlen for example  1309: 190
# Maxlen for example  1310: 117
# Maxlen for example  1311: 148
# Maxlen for example  1312: 133
# Maxlen for example  1313: 194
# Maxlen for example  1314: 128
# Maxlen for example  1315: 362
# Maxlen for example  1316: 219
# Maxlen for example  1317: 132
# Maxlen for example  1318: 166
# Maxlen for example  1319: 131
# Maxlen for example  1320: 168
# Maxlen for example  1321: 236
# Maxlen for example  1322: 115
# Maxlen for example  1323: 191
# Maxlen for example  1324: 149
# Maxlen for example  1325: 121
# Maxlen for example  1326: 341
# Maxlen for example  1327: 185
# Maxlen for example  1328: 162
# Maxlen for example  1329: 122
# Maxlen for example  1330: 177
# Maxlen for example  1331: 114
# Maxlen for example  1332: 167
# Maxlen for example  1333: 173
# Maxlen for example  1334: 173
# Maxlen for example  1335: 296
# Maxlen for example  1336: 132
# Maxlen for example  1337: 116
# Maxlen for example  1338: 171
# Maxlen for example  1339: 131
# Maxlen for example  1340: 228
# Maxlen for example  1341: 172
# Maxlen for example  1342: 131
# Maxlen for example  1343: 136
# Maxlen for example  1344: 141
# Maxlen for example  1345: 184
# Maxlen for example  1346: 259
# Maxlen for example  1347: 187
# Maxlen for example  1348: 257
# Maxlen for example  1349: 233
# Maxlen for example  1350: 240
# Maxlen for example  1351: 193
# Maxlen for example  1352: 133
# Maxlen for example  1353: 184
# Maxlen for example  1354: 272
# Maxlen for example  1355: 135
# Maxlen for example  1356: 201
# Maxlen for example  1357: 129
# Maxlen for example  1358: 160
# Maxlen for example  1359: 221
# Maxlen for example  1360: 121
# Maxlen for example  1361: 141
# Maxlen for example  1362: 145
# Maxlen for example  1363: 160
# Maxlen for example  1364: 148
# Maxlen for example  1365: 234
# Maxlen for example  1366: 136
# Maxlen for example  1367: 145
# Maxlen for example  1368: 333
# Maxlen for example  1369: 115
# Maxlen for example  1370: 137
# Maxlen for example  1371: 253
# Maxlen for example  1372: 179
# Maxlen for example  1373: 164
# Maxlen for example  1374: 165
# Maxlen for example  1375: 200
# Maxlen for example  1376: 125
# Maxlen for example  1377: 120
# Maxlen for example  1378: 118
# Maxlen for example  1379: 189
# Maxlen for example  1380: 283
# Maxlen for example  1381: 137
# Maxlen for example  1382: 137
# Maxlen for example  1383: 136
# Maxlen for example  1384: 159
# Maxlen for example  1385: 238
# Maxlen for example  1386: 163
# Maxlen for example  1387: 138
# Maxlen for example  1388: 112
# Maxlen for example  1389: 162
# Maxlen for example  1390: 192
# Maxlen for example  1391: 298
# Maxlen for example  1392: 179
# Maxlen for example  1393: 153
# Maxlen for example  1394: 269
# Maxlen for example  1395: 148
# Maxlen for example  1396: 231
# Maxlen for example  1397: 118
# Maxlen for example  1398: 161
# Maxlen for example  1399: 143
# Maxlen for example  1400: 256
# Maxlen for example  1401: 190
# Maxlen for example  1402: 183
# Maxlen for example  1403: 201
# Maxlen for example  1404: 120
# Maxlen for example  1405: 180
# Maxlen for example  1406: 167
# Maxlen for example  1407: 147
# Maxlen for example  1408: 288
# Maxlen for example  1409: 113
# Maxlen for example  1410: 170
# Maxlen for example  1411: 234
# Maxlen for example  1412: 233
# Maxlen for example  1413: 119
# Maxlen for example  1414: 244
# Maxlen for example  1415: 128
# Maxlen for example  1416: 125
# Maxlen for example  1417: 166
# Maxlen for example  1418: 300
# Maxlen for example  1419: 113
# Maxlen for example  1420: 283
# Maxlen for example  1421: 181
# Maxlen for example  1422: 154
# Maxlen for example  1423: 189
# Maxlen for example  1424: 122
# Maxlen for example  1425: 242
# Maxlen for example  1426: 254
# Maxlen for example  1427: 182
# Maxlen for example  1428: 137
# Maxlen for example  1429: 153
# Maxlen for example  1430: 193
# Maxlen for example  1431: 124
# Maxlen for example  1432: 132
# Maxlen for example  1433: 193
# Maxlen for example  1434: 225
# Maxlen for example  1435: 285
# Maxlen for example  1436: 140
# Maxlen for example  1437: 218
# Maxlen for example  1438: 207
# Maxlen for example  1439: 175
# Maxlen for example  1440: 139
# Maxlen for example  1441: 135
# Maxlen for example  1442: 323
# Maxlen for example  1443: 164
# Maxlen for example  1444: 129
# Maxlen for example  1445: 188
# Maxlen for example  1446: 156
# Maxlen for example  1447: 179
# Maxlen for example  1448: 216
# Maxlen for example  1449: 292
# Maxlen for example  1450: 129
# Maxlen for example  1451: 117
# Maxlen for example  1452: 154
# Maxlen for example  1453: 114
# Maxlen for example  1454: 312
# Maxlen for example  1455: 211
# Maxlen for example  1456: 309
# Maxlen for example  1457: 195
# Maxlen for example  1458: 170
# Maxlen for example  1459: 129
# Maxlen for example  1460: 295
# Maxlen for example  1461: 299
# Maxlen for example  1462: 178
# Maxlen for example  1463: 178
# Maxlen for example  1464: 199
# Maxlen for example  1465: 245
# Maxlen for example  1466: 180
# Maxlen for example  1467: 140
# Maxlen for example  1468: 279
# Maxlen for example  1469: 287
# Maxlen for example  1470: 147
# Maxlen for example  1471: 355
# Maxlen for example  1472: 149
# Maxlen for example  1473: 185
# Maxlen for example  1474: 205
# Maxlen for example  1475: 167
# Maxlen for example  1476: 169
# Maxlen for example  1477: 136
# Maxlen for example  1478: 114
# Maxlen for example  1479: 193
# Maxlen for example  1480: 179
# Maxlen for example  1481: 119
# Maxlen for example  1482: 199
# Maxlen for example  1483: 154
# Maxlen for example  1484: 124
# Maxlen for example  1485: 197
# Maxlen for example  1486: 228
# Maxlen for example  1487: 125
# Maxlen for example  1488: 118
# Maxlen for example  1489: 177
# Maxlen for example  1490: 287
# Maxlen for example  1491: 182
# Maxlen for example  1492: 189
# Maxlen for example  1493: 146
# Maxlen for example  1494: 114
# Maxlen for example  1495: 135
# Maxlen for example  1496: 111
# Maxlen for example  1497: 293
# Maxlen for example  1498: 144
# Maxlen for example  1499: 130
# Maxlen for example  1500: 233
# Maxlen for example  1501: 208
# Maxlen for example  1502: 150
# Maxlen for example  1503: 179
# Maxlen for example  1504: 209
# Maxlen for example  1505: 140
# Maxlen for example  1506: 115
# Maxlen for example  1507: 138
# Maxlen for example  1508: 250
# Maxlen for example  1509: 245
# Maxlen for example  1510: 374
# Maxlen for example  1511: 115
# Maxlen for example  1512: 182
# Maxlen for example  1513: 135
# Maxlen for example  1514: 188
# Maxlen for example  1515: 210
# Maxlen for example  1516: 144
# Maxlen for example  1517: 141
# Maxlen for example  1518: 283
# Maxlen for example  1519: 210
# Maxlen for example  1520: 196
# Maxlen for example  1521: 122
# Maxlen for example  1522: 306
# Maxlen for example  1523: 235
# Maxlen for example  1524: 182
# Maxlen for example  1525: 316
# Maxlen for example  1526: 334
# Maxlen for example  1527: 212
# Maxlen for example  1528: 126
# Maxlen for example  1529: 137
# Maxlen for example  1530: 134
# Maxlen for example  1531: 130
# Maxlen for example  1532: 195
# Maxlen for example  1533: 120
# Maxlen for example  1534: 167
# Maxlen for example  1535: 306
# Maxlen for example  1536: 192
# Maxlen for example  1537: 155
# Maxlen for example  1538: 188
# Maxlen for example  1539: 119
# Maxlen for example  1540: 185
# Maxlen for example  1541: 165
# Maxlen for example  1542: 298
# Maxlen for example  1543: 208
# Maxlen for example  1544: 220
# Maxlen for example  1545: 121
# Maxlen for example  1546: 182
# Maxlen for example  1547: 183
# Maxlen for example  1548: 269
# Maxlen for example  1549: 117
# Maxlen for example  1550: 162
# Maxlen for example  1551: 140
# Maxlen for example  1552: 139
# Maxlen for example  1553: 296
# Maxlen for example  1554: 247
# Maxlen for example  1555: 133
# Maxlen for example  1556: 168
# Maxlen for example  1557: 173
# Maxlen for example  1558: 133
# Maxlen for example  1559: 272
# Maxlen for example  1560: 190
# Maxlen for example  1561: 156
# Maxlen for example  1562: 197
# Maxlen for example  1563: 173
# Maxlen for example  1564: 126
# Maxlen for example  1565: 149
# Maxlen for example  1566: 117
# Maxlen for example  1567: 228
# Maxlen for example  1568: 121
# Maxlen for example  1569: 259
# Maxlen for example  1570: 179
# Maxlen for example  1571: 142
# Maxlen for example  1572: 114
# Maxlen for example  1573: 287
# Maxlen for example  1574: 193
# Maxlen for example  1575: 121
# Maxlen for example  1576: 126
# Maxlen for example  1577: 119
# Maxlen for example  1578: 113
# Maxlen for example  1579: 361
# Maxlen for example  1580: 194
# Maxlen for example  1581: 288
# Maxlen for example  1582: 188
# Maxlen for example  1583: 123
# Maxlen for example  1584: 138
# Maxlen for example  1585: 243
# Maxlen for example  1586: 117
# Maxlen for example  1587: 140
# Maxlen for example  1588: 262
# Maxlen for example  1589: 263
# Maxlen for example  1590: 185
# Maxlen for example  1591: 253
# Maxlen for example  1592: 278
# Maxlen for example  1593: 143
# Maxlen for example  1594: 200
# Maxlen for example  1595: 140
# Maxlen for example  1596: 192
# Maxlen for example  1597: 194
# Maxlen for example  1598: 323
# Maxlen for example  1599: 146
# Maxlen for example  1600: 174
# ...
# Maxlen for example  7469: 177
# Maxlen for example  7470: 151
# Maxlen for example  7471: 128
# Maxlen for example  7472: 120
# Maxlen for example  7473: 134
# Maxlen for example  7474: 138
# Maxlen for example  7475: 213
# Maxlen for example  7476: 194
# Maxlen for example  7477: 284
# Maxlen for example  7478: 314
# Maxlen for example  7479: 220
# Maxlen for example  7480: 217
# Maxlen for example  7481: 118
# Maxlen for example  7482: 254
# Maxlen for example  7483: 149
# Maxlen for example  7484: 249
# Maxlen for example  7485: 261
# Maxlen for example  7486: 209
# Maxlen for example  7487: 234
# Maxlen for example  7488: 196
# Maxlen for example  7489: 175
# Maxlen for example  7490: 309
# Maxlen for example  7491: 191
# Maxlen for example  7492: 168
# Maxlen for example  7493: 116
# Maxlen for example  7494: 203
# Maxlen for example  7495: 121
# Maxlen for example  7496: 157
# Maxlen for example  7497: 122
# Maxlen for example  7498: 148
# Maxlen for example  7499: 290
# Maxlen for example  7500: 195
# Maxlen for example  7501: 295
# Maxlen for example  7502: 122
# Maxlen for example  7503: 141
# Maxlen for example  7504: 122
# Maxlen for example  7505: 145
# Maxlen for example  7506: 290
# Maxlen for example  7507: 120
# Maxlen for example  7508: 153
# Maxlen for example  7509: 129
# Maxlen for example  7510: 171
# Maxlen for example  7511: 164
# Maxlen for example  7512: 131
# Maxlen for example  7513: 141
# Maxlen for example  7514: 242
# Maxlen for example  7515: 149
# Maxlen for example  7516: 133
# Maxlen for example  7517: 129
# Maxlen for example  7518: 264
# Maxlen for example  7519: 299
# Maxlen for example  7520: 302
# Maxlen for example  7521: 119
# Maxlen for example  7522: 191
# Maxlen for example  7523: 265
# Maxlen for example  7524: 131
# Maxlen for example  7525: 196
# Maxlen for example  7526: 266
# Maxlen for example  7527: 144
# Maxlen for example  7528: 264
# Maxlen for example  7529: 123
# Maxlen for example  7530: 200
# Maxlen for example  7531: 278
# Maxlen for example  7532: 189
# Maxlen for example  7533: 123
# Maxlen for example  7534: 272
# Maxlen for example  7535: 288
# Maxlen for example  7536: 200
# Maxlen for example  7537: 121
# Maxlen for example  7538: 215
# Maxlen for example  7539: 322
# Maxlen for example  7540: 123
# Maxlen for example  7541: 143
# Maxlen for example  7542: 233
# Maxlen for example  7543: 120
# Maxlen for example  7544: 149
# Maxlen for example  7545: 275
# Maxlen for example  7546: 274
# Maxlen for example  7547: 127
# Maxlen for example  7548: 131
# Maxlen for example  7549: 286
# Maxlen for example  7550: 142
# Maxlen for example  7551: 207
# Maxlen for example  7552: 182
# Maxlen for example  7553: 184
# Maxlen for example  7554: 277
# Maxlen for example  7555: 297
# Maxlen for example  7556: 329
# Maxlen for example  7557: 177
# Maxlen for example  7558: 191
# Maxlen for example  7559: 346
# Maxlen for example  7560: 310
# Maxlen for example  7561: 321
# Maxlen for example  7562: 146
# Maxlen for example  7563: 157
# Maxlen for example  7564: 203
# Maxlen for example  7565: 182
# Maxlen for example  7566: 124
# Maxlen for example  7567: 315
# Maxlen for example  7568: 196
# Maxlen for example  7569: 131
# Maxlen for example  7570: 146
# Maxlen for example  7571: 271
# Maxlen for example  7572: 119
# Maxlen for example  7573: 184
# Maxlen for example  7574: 259
# Maxlen for example  7575: 117
# Maxlen for example  7576: 141
# Maxlen for example  7577: 115
# Maxlen for example  7578: 316
# Maxlen for example  7579: 151
# Maxlen for example  7580: 124
# Maxlen for example  7581: 183
# Maxlen for example  7582: 186
# Maxlen for example  7583: 142
# Maxlen for example  7584: 119
# Maxlen for example  7585: 167
# Maxlen for example  7586: 270
# Maxlen for example  7587: 129
# Maxlen for example  7588: 122
# Maxlen for example  7589: 246
# Maxlen for example  7590: 184
# Maxlen for example  7591: 319
# Maxlen for example  7592: 220
# Maxlen for example  7593: 230
# Maxlen for example  7594: 123
# Maxlen for example  7595: 265
# Maxlen for example  7596: 234
# Maxlen for example  7597: 193
# Maxlen for example  7598: 128
# Maxlen for example  7599: 183
# Maxlen for example  7600: 163
# Maxlen for example  7601: 192
# Maxlen for example  7602: 122
# Maxlen for example  7603: 173
# Maxlen for example  7604: 124
# Maxlen for example  7605: 274
# Maxlen for example  7606: 206
# Maxlen for example  7607: 187
# Maxlen for example  7608: 270
# Maxlen for example  7609: 120
# Maxlen for example  7610: 226
# Maxlen for example  7611: 274
# Maxlen for example  7612: 161
# Maxlen for example  7613: 222
# Maxlen for example  7614: 114
# Maxlen for example  7615: 202
# Maxlen for example  7616: 188
# Maxlen for example  7617: 188
# Maxlen for example  7618: 129
# Maxlen for example  7619: 122
# Maxlen for example  7620: 127
# Maxlen for example  7621: 240
# Maxlen for example  7622: 176
# Maxlen for example  7623: 306
# Maxlen for example  7624: 178
# Maxlen for example  7625: 273
# Maxlen for example  7626: 170
# Maxlen for example  7627: 127
# Maxlen for example  7628: 211
# Maxlen for example  7629: 218
# Maxlen for example  7630: 143
# Maxlen for example  7631: 120
# Maxlen for example  7632: 161
# Maxlen for example  7633: 172
# Maxlen for example  7634: 120
# Maxlen for example  7635: 208
# Maxlen for example  7636: 134
# Maxlen for example  7637: 237
# Maxlen for example  7638: 284
# Maxlen for example  7639: 124
# Maxlen for example  7640: 232
# Maxlen for example  7641: 141
# Maxlen for example  7642: 184
# Maxlen for example  7643: 262
# Maxlen for example  7644: 187
# Maxlen for example  7645: 308
# Maxlen for example  7646: 126
# Maxlen for example  7647: 121
# Maxlen for example  7648: 192
# Maxlen for example  7649: 171
# Maxlen for example  7650: 122
# Maxlen for example  7651: 181
# Maxlen for example  7652: 127
# Maxlen for example  7653: 210
# Maxlen for example  7654: 130
# Maxlen for example  7655: 209
# Maxlen for example  7656: 188
# Maxlen for example  7657: 144
# Maxlen for example  7658: 220
# Maxlen for example  7659: 187
# Maxlen for example  7660: 123
# Maxlen for example  7661: 317
# Maxlen for example  7662: 129
# Maxlen for example  7663: 121
# Maxlen for example  7664: 260
# Maxlen for example  7665: 135
# Maxlen for example  7666: 136
# Maxlen for example  7667: 208
# Maxlen for example  7668: 124
# Maxlen for example  7669: 205
# Maxlen for example  7670: 128
# Maxlen for example  7671: 226
# Maxlen for example  7672: 147
# Maxlen for example  7673: 276
# Maxlen for example  7674: 189
# Maxlen for example  7675: 178
# Maxlen for example  7676: 128
# Maxlen for example  7677: 126
# Maxlen for example  7678: 216
# Maxlen for example  7679: 118
# Maxlen for example  7680: 155
# Maxlen for example  7681: 265
# Maxlen for example  7682: 128
# Maxlen for example  7683: 134
# Maxlen for example  7684: 302
# Maxlen for example  7685: 115
# Maxlen for example  7686: 301
# Maxlen for example  7687: 280
# Maxlen for example  7688: 201
# Maxlen for example  7689: 248
# Maxlen for example  7690: 256
# Maxlen for example  7691: 137
# Maxlen for example  7692: 232
# Maxlen for example  7693: 270
# Maxlen for example  7694: 179
# Maxlen for example  7695: 120
# Maxlen for example  7696: 160
# Maxlen for example  7697: 156
# Maxlen for example  7698: 327
# Maxlen for example  7699: 322
# Maxlen for example  7700: 235
# Maxlen for example  7701: 223
# Maxlen for example  7702: 192
# Maxlen for example  7703: 262
# Maxlen for example  7704: 181
# Maxlen for example  7705: 149
# Maxlen for example  7706: 127
# Maxlen for example  7707: 135
# Maxlen for example  7708: 198
# Maxlen for example  7709: 235
# Maxlen for example  7710: 309
# Maxlen for example  7711: 135
# Maxlen for example  7712: 145
# Maxlen for example  7713: 277
# Maxlen for example  7714: 187
# Maxlen for example  7715: 125
# Maxlen for example  7716: 189
# Maxlen for example  7717: 127
# Maxlen for example  7718: 148
# Maxlen for example  7719: 129
# Maxlen for example  7720: 179
# Maxlen for example  7721: 257
# Maxlen for example  7722: 246
# Maxlen for example  7723: 140
# Maxlen for example  7724: 185
# Maxlen for example  7725: 120
# Maxlen for example  7726: 187
# Maxlen for example  7727: 159
# Maxlen for example  7728: 123
# Maxlen for example  7729: 162
# Maxlen for example  7730: 147
# Maxlen for example  7731: 127
# Maxlen for example  7732: 208
# Maxlen for example  7733: 125
# Maxlen for example  7734: 146
# Maxlen for example  7735: 231
# Maxlen for example  7736: 124
# Maxlen for example  7737: 228
# Maxlen for example  7738: 189
# Maxlen for example  7739: 254
# Maxlen for example  7740: 162
# Maxlen for example  7741: 192
# Maxlen for example  7742: 122
# Maxlen for example  7743: 229
# Maxlen for example  7744: 182
# Maxlen for example  7745: 180
# Maxlen for example  7746: 142
# Maxlen for example  7747: 115
# Maxlen for example  7748: 194
# Maxlen for example  7749: 233
# Maxlen for example  7750: 152
# Maxlen for example  7751: 219
# Maxlen for example  7752: 182
# Maxlen for example  7753: 119
# Maxlen for example  7754: 124
# Maxlen for example  7755: 133
# Maxlen for example  7756: 184
# Maxlen for example  7757: 151
# Maxlen for example  7758: 141
# Maxlen for example  7759: 169
# Maxlen for example  7760: 141
# Maxlen for example  7761: 192
# Maxlen for example  7762: 234
# Maxlen for example  7763: 186
# Maxlen for example  7764: 141
# Maxlen for example  7765: 130
# Maxlen for example  7766: 238
# Maxlen for example  7767: 193
# Maxlen for example  7768: 140
# Maxlen for example  7769: 169
# Maxlen for example  7770: 163
# Maxlen for example  7771: 127
# Maxlen for example  7772: 130
# Maxlen for example  7773: 225
# Maxlen for example  7774: 337
# Maxlen for example  7775: 117
# Maxlen for example  7776: 220
# Maxlen for example  7777: 281
# Maxlen for example  7778: 179
# Maxlen for example  7779: 135
# Maxlen for example  7780: 161
# Maxlen for example  7781: 113
# Maxlen for example  7782: 328
# Maxlen for example  7783: 333
# Maxlen for example  7784: 195
# Maxlen for example  7785: 203
# Maxlen for example  7786: 139
# Maxlen for example  7787: 133
# Maxlen for example  7788: 144
# Maxlen for example  7789: 190
# Maxlen for example  7790: 338
# Maxlen for example  7791: 152
# Maxlen for example  7792: 236
# Maxlen for example  7793: 149
# Maxlen for example  7794: 131
# Maxlen for example  7795: 182
# Maxlen for example  7796: 193
# Maxlen for example  7797: 279
# Maxlen for example  7798: 266
# Maxlen for example  7799: 166
# Maxlen for example  7800: 194
# Maxlen for example  7801: 117
# Maxlen for example  7802: 176
# Maxlen for example  7803: 257
# Maxlen for example  7804: 185
# Maxlen for example  7805: 252
# Maxlen for example  7806: 132
# Maxlen for example  7807: 118
# Maxlen for example  7808: 139
# Maxlen for example  7809: 324
# Maxlen for example  7810: 217
# Maxlen for example  7811: 191
# Maxlen for example  7812: 120
# Maxlen for example  7813: 140
# Maxlen for example  7814: 175
# Maxlen for example  7815: 144
# Maxlen for example  7816: 264
# Maxlen for example  7817: 149
# Maxlen for example  7818: 199
# Maxlen for example  7819: 133
# Maxlen for example  7820: 121
# Maxlen for example  7821: 249
# Maxlen for example  7822: 242
# Maxlen for example  7823: 196
# Maxlen for example  7824: 289
# Maxlen for example  7825: 125
# Maxlen for example  7826: 314
# Maxlen for example  7827: 154
# Maxlen for example  7828: 124
# Maxlen for example  7829: 135
# Maxlen for example  7830: 274
# Maxlen for example  7831: 124
# Maxlen for example  7832: 149
# Maxlen for example  7833: 126
# Maxlen for example  7834: 184
# Maxlen for example  7835: 117
# Maxlen for example  7836: 124
# Maxlen for example  7837: 133
# Maxlen for example  7838: 142
# Maxlen for example  7839: 121
# Maxlen for example  7840: 125
# Maxlen for example  7841: 185
# Maxlen for example  7842: 192
# Maxlen for example  7843: 188
# Maxlen for example  7844: 169
# Maxlen for example  7845: 145
# Maxlen for example  7846: 213
# Maxlen for example  7847: 157
# Maxlen for example  7848: 123
# Maxlen for example  7849: 197
# Maxlen for example  7850: 181
# Maxlen for example  7851: 123
# Maxlen for example  7852: 174
# Maxlen for example  7853: 124
# Maxlen for example  7854: 269
# Maxlen for example  7855: 201
# Maxlen for example  7856: 156
# Maxlen for example  7857: 117
# Maxlen for example  7858: 136
# Maxlen for example  7859: 132
# Maxlen for example  7860: 133
# Maxlen for example  7861: 143
# Maxlen for example  7862: 307
# Maxlen for example  7863: 123
# Maxlen for example  7864: 310
# Maxlen for example  7865: 146
# Maxlen for example  7866: 208
# Maxlen for example  7867: 178
# Maxlen for example  7868: 132
# Maxlen for example  7869: 123
# Maxlen for example  7870: 128
# Maxlen for example  7871: 249
# Maxlen for example  7872: 139
# Maxlen for example  7873: 153
# Maxlen for example  7874: 292
# Maxlen for example  7875: 232
# Maxlen for example  7876: 128
# Maxlen for example  7877: 254
# Maxlen for example  7878: 120
# Maxlen for example  7879: 166
# Maxlen for example  7880: 335
# Maxlen for example  7881: 304
# Maxlen for example  7882: 143
# Maxlen for example  7883: 200
# Maxlen for example  7884: 158
# Maxlen for example  7885: 208
# Maxlen for example  7886: 207
# Maxlen for example  7887: 135
# Maxlen for example  7888: 174
# Maxlen for example  7889: 142
# Maxlen for example  7890: 123
# Maxlen for example  7891: 144
# Maxlen for example  7892: 164
# Maxlen for example  7893: 149
# Maxlen for example  7894: 144
# Maxlen for example  7895: 117
# Maxlen for example  7896: 208
# Maxlen for example  7897: 174
# Maxlen for example  7898: 203
# Maxlen for example  7899: 123
# Maxlen for example  7900: 156
# Maxlen for example  7901: 146
# Maxlen for example  7902: 249
# Maxlen for example  7903: 191
# Maxlen for example  7904: 227
# Maxlen for example  7905: 129
# Maxlen for example  7906: 123
# Maxlen for example  7907: 252
# Maxlen for example  7908: 179
# Maxlen for example  7909: 143
# Maxlen for example  7910: 123
# Maxlen for example  7911: 191
# Maxlen for example  7912: 309
# Maxlen for example  7913: 119
# Maxlen for example  7914: 237
# Maxlen for example  7915: 311
# Maxlen for example  7916: 180
# Maxlen for example  7917: 313
# Maxlen for example  7918: 147
# Maxlen for example  7919: 281
# Maxlen for example  7920: 145
# Maxlen for example  7921: 151
# Maxlen for example  7922: 261
# Maxlen for example  7923: 218
# Maxlen for example  7924: 117
# Maxlen for example  7925: 259
# Maxlen for example  7926: 176
# Maxlen for example  7927: 253
# Maxlen for example  7928: 175
# Maxlen for example  7929: 117
# Maxlen for example  7930: 110
# Maxlen for example  7931: 193
# Maxlen for example  7932: 203
# Maxlen for example  7933: 203
# Maxlen for example  7934: 221
# Maxlen for example  7935: 209
# Maxlen for example  7936: 144
# Maxlen for example  7937: 177
# Maxlen for example  7938: 152
# Maxlen for example  7939: 215
# Maxlen for example  7940: 294
# Maxlen for example  7941: 212
# Maxlen for example  7942: 114
# Maxlen for example  7943: 301
# Maxlen for example  7944: 210
# Maxlen for example  7945: 121
# Maxlen for example  7946: 120
# Maxlen for example  7947: 260
# Maxlen for example  7948: 123
# Maxlen for example  7949: 129
# Maxlen for example  7950: 119
# Maxlen for example  7951: 193
# Maxlen for example  7952: 183
# Maxlen for example  7953: 214
# Maxlen for example  7954: 190
# Maxlen for example  7955: 142
# Maxlen for example  7956: 175
# Maxlen for example  7957: 124
# Maxlen for example  7958: 178
# Maxlen for example  7959: 273
# Maxlen for example  7960: 231
# Maxlen for example  7961: 117
# Maxlen for example  7962: 196
# Maxlen for example  7963: 156
# Maxlen for example  7964: 180
# Maxlen for example  7965: 123
# Maxlen for example  7966: 142
# Maxlen for example  7967: 245
# Maxlen for example  7968: 121
# Maxlen for example  7969: 283
# Maxlen for example  7970: 164
# Maxlen for example  7971: 188
# Maxlen for example  7972: 142
# Maxlen for example  7973: 198
# Maxlen for example  7974: 130
# Maxlen for example  7975: 185
# Maxlen for example  7976: 132
# Maxlen for example  7977: 175
# Maxlen for example  7978: 244
# Maxlen for example  7979: 139
# Maxlen for example  7980: 215
# Maxlen for example  7981: 121
# Maxlen for example  7982: 191
# Maxlen for example  7983: 227
# Maxlen for example  7984: 187
# Maxlen for example  7985: 150
# Maxlen for example  7986: 146
# Maxlen for example  7987: 119
# Maxlen for example  7988: 180
# Maxlen for example  7989: 128
# Maxlen for example  7990: 120
# Maxlen for example  7991: 351
# Maxlen for example  7992: 203
# Maxlen for example  7993: 151
# Maxlen for example  7994: 196
# Maxlen for example  7995: 189
# Maxlen for example  7996: 178
# Maxlen for example  7997: 138
# Maxlen for example  7998: 337
# Maxlen for example  7999: 169
# Maxlen for example  8000: 122
# All maxlen: 403

# %%
all_maxlen = 0
for i, cd in enumerate(val_data):
    fields = flatten_fields(cd)
    maxlen = 0
    for f in fields:
        tokens = tokenizer(f, return_tensors='pt', padding=True)
        maxlen = max(maxlen, tokens['input_ids'].shape[1])
    print(f'Maxlen for example {i+1:5}: {maxlen}')
    all_maxlen = max(all_maxlen, maxlen)

print(f'All maxlen: {all_maxlen}')
# Out:
# Maxlen for example     1: 196
# Maxlen for example     2: 124
# Maxlen for example     3: 191
# Maxlen for example     4: 129
# Maxlen for example     5: 168
# Maxlen for example     6: 291
# Maxlen for example     7: 190
# Maxlen for example     8: 250
# Maxlen for example     9: 180
# Maxlen for example    10: 237
# Maxlen for example    11: 131
# Maxlen for example    12: 135
# Maxlen for example    13: 133
# Maxlen for example    14: 209
# Maxlen for example    15: 145
# Maxlen for example    16: 177
# Maxlen for example    17: 269
# Maxlen for example    18: 180
# Maxlen for example    19: 208
# Maxlen for example    20: 286
# Maxlen for example    21: 158
# Maxlen for example    22: 326
# Maxlen for example    23: 197
# Maxlen for example    24: 298
# Maxlen for example    25: 197
# Maxlen for example    26: 199
# Maxlen for example    27: 195
# Maxlen for example    28: 353
# Maxlen for example    29: 208
# Maxlen for example    30: 288
# Maxlen for example    31: 162
# Maxlen for example    32: 144
# Maxlen for example    33: 182
# Maxlen for example    34: 136
# Maxlen for example    35: 146
# Maxlen for example    36: 182
# Maxlen for example    37: 167
# Maxlen for example    38: 123
# Maxlen for example    39: 327
# Maxlen for example    40: 203
# Maxlen for example    41: 123
# Maxlen for example    42: 176
# Maxlen for example    43: 228
# Maxlen for example    44: 314
# Maxlen for example    45: 125
# Maxlen for example    46: 149
# Maxlen for example    47: 281
# Maxlen for example    48: 137
# Maxlen for example    49: 141
# Maxlen for example    50: 120
# Maxlen for example    51: 275
# Maxlen for example    52: 223
# Maxlen for example    53: 205
# Maxlen for example    54: 112
# Maxlen for example    55: 136
# Maxlen for example    56: 185
# Maxlen for example    57: 195
# Maxlen for example    58: 202
# Maxlen for example    59: 239
# Maxlen for example    60: 118
# Maxlen for example    61: 279
# Maxlen for example    62: 148
# Maxlen for example    63: 310
# Maxlen for example    64: 196
# Maxlen for example    65: 171
# Maxlen for example    66: 178
# Maxlen for example    67: 187
# Maxlen for example    68: 199
# Maxlen for example    69: 227
# Maxlen for example    70: 125
# Maxlen for example    71: 177
# Maxlen for example    72: 274
# Maxlen for example    73: 168
# Maxlen for example    74: 127
# Maxlen for example    75: 374
# Maxlen for example    76: 216
# Maxlen for example    77: 145
# Maxlen for example    78: 321
# Maxlen for example    79: 142
# Maxlen for example    80: 210
# Maxlen for example    81: 210
# Maxlen for example    82: 187
# Maxlen for example    83: 138
# Maxlen for example    84: 192
# Maxlen for example    85: 286
# Maxlen for example    86: 197
# Maxlen for example    87: 117
# Maxlen for example    88: 311
# Maxlen for example    89: 121
# Maxlen for example    90: 315
# Maxlen for example    91: 119
# Maxlen for example    92: 121
# Maxlen for example    93: 121
# Maxlen for example    94: 129
# Maxlen for example    95: 114
# Maxlen for example    96: 125
# Maxlen for example    97: 181
# Maxlen for example    98: 183
# Maxlen for example    99: 121
# Maxlen for example   100: 260
# Maxlen for example   101: 203
# Maxlen for example   102: 234
# Maxlen for example   103: 183
# Maxlen for example   104: 170
# Maxlen for example   105: 155
# Maxlen for example   106: 131
# Maxlen for example   107: 199
# Maxlen for example   108: 141
# Maxlen for example   109: 123
# Maxlen for example   110: 124
# Maxlen for example   111: 205
# Maxlen for example   112: 287
# Maxlen for example   113: 165
# Maxlen for example   114: 156
# Maxlen for example   115: 169
# Maxlen for example   116: 221
# Maxlen for example   117: 234
# Maxlen for example   118: 262
# Maxlen for example   119: 177
# Maxlen for example   120: 241
# Maxlen for example   121: 182
# Maxlen for example   122: 152
# Maxlen for example   123: 130
# Maxlen for example   124: 224
# Maxlen for example   125: 109
# Maxlen for example   126: 125
# Maxlen for example   127: 137
# Maxlen for example   128: 333
# Maxlen for example   129: 165
# Maxlen for example   130: 196
# Maxlen for example   131: 214
# Maxlen for example   132: 297
# Maxlen for example   133: 210
# Maxlen for example   134: 238
# Maxlen for example   135: 186
# Maxlen for example   136: 179
# Maxlen for example   137: 260
# Maxlen for example   138: 173
# Maxlen for example   139: 220
# Maxlen for example   140: 137
# Maxlen for example   141: 167
# Maxlen for example   142: 239
# Maxlen for example   143: 243
# Maxlen for example   144: 190
# Maxlen for example   145: 204
# Maxlen for example   146: 182
# Maxlen for example   147: 137
# Maxlen for example   148: 286
# Maxlen for example   149: 359
# Maxlen for example   150: 230
# Maxlen for example   151: 221
# Maxlen for example   152: 177
# Maxlen for example   153: 152
# Maxlen for example   154: 245
# Maxlen for example   155: 120
# Maxlen for example   156: 188
# Maxlen for example   157: 187
# Maxlen for example   158: 154
# Maxlen for example   159: 276
# Maxlen for example   160: 137
# Maxlen for example   161: 154
# Maxlen for example   162: 194
# Maxlen for example   163: 174
# Maxlen for example   164: 258
# Maxlen for example   165: 125
# Maxlen for example   166: 136
# Maxlen for example   167: 124
# Maxlen for example   168: 183
# Maxlen for example   169: 139
# Maxlen for example   170: 309
# Maxlen for example   171: 138
# Maxlen for example   172: 149
# Maxlen for example   173: 300
# Maxlen for example   174: 207
# Maxlen for example   175: 191
# Maxlen for example   176: 225
# Maxlen for example   177: 134
# Maxlen for example   178: 194
# Maxlen for example   179: 125
# Maxlen for example   180: 147
# Maxlen for example   181: 140
# Maxlen for example   182: 175
# Maxlen for example   183: 119
# Maxlen for example   184: 188
# Maxlen for example   185: 130
# Maxlen for example   186: 132
# Maxlen for example   187: 125
# Maxlen for example   188: 287
# Maxlen for example   189: 120
# Maxlen for example   190: 158
# Maxlen for example   191: 136
# Maxlen for example   192: 172
# Maxlen for example   193: 132
# Maxlen for example   194: 146
# Maxlen for example   195: 141
# Maxlen for example   196: 264
# Maxlen for example   197: 159
# Maxlen for example   198: 122
# Maxlen for example   199: 258
# Maxlen for example   200: 216
# Maxlen for example   201: 145
# Maxlen for example   202: 205
# Maxlen for example   203: 268
# Maxlen for example   204: 141
# Maxlen for example   205: 253
# Maxlen for example   206: 308
# Maxlen for example   207: 195
# Maxlen for example   208: 192
# Maxlen for example   209: 132
# Maxlen for example   210: 232
# Maxlen for example   211: 122
# Maxlen for example   212: 205
# Maxlen for example   213: 165
# Maxlen for example   214: 118
# Maxlen for example   215: 178
# Maxlen for example   216: 204
# Maxlen for example   217: 178
# Maxlen for example   218: 126
# Maxlen for example   219: 154
# Maxlen for example   220: 295
# Maxlen for example   221: 278
# Maxlen for example   222: 158
# Maxlen for example   223: 133
# Maxlen for example   224: 237
# Maxlen for example   225: 213
# Maxlen for example   226: 144
# Maxlen for example   227: 144
# Maxlen for example   228: 282
# Maxlen for example   229: 198
# Maxlen for example   230: 199
# Maxlen for example   231: 175
# Maxlen for example   232: 133
# Maxlen for example   233: 137
# Maxlen for example   234: 120
# Maxlen for example   235: 173
# Maxlen for example   236: 143
# Maxlen for example   237: 176
# Maxlen for example   238: 176
# Maxlen for example   239: 127
# Maxlen for example   240: 147
# Maxlen for example   241: 138
# Maxlen for example   242: 145
# Maxlen for example   243: 275
# Maxlen for example   244: 108
# Maxlen for example   245: 115
# Maxlen for example   246: 219
# Maxlen for example   247: 132
# Maxlen for example   248: 329
# Maxlen for example   249: 258
# Maxlen for example   250: 129
# Maxlen for example   251: 132
# Maxlen for example   252: 150
# Maxlen for example   253: 195
# Maxlen for example   254: 139
# Maxlen for example   255: 217
# Maxlen for example   256: 129
# Maxlen for example   257: 127
# Maxlen for example   258: 195
# Maxlen for example   259: 150
# Maxlen for example   260: 267
# Maxlen for example   261: 140
# Maxlen for example   262: 117
# Maxlen for example   263: 239
# Maxlen for example   264: 282
# Maxlen for example   265: 208
# Maxlen for example   266: 141
# Maxlen for example   267: 187
# Maxlen for example   268: 121
# Maxlen for example   269: 119
# Maxlen for example   270: 184
# Maxlen for example   271: 140
# Maxlen for example   272: 230
# Maxlen for example   273: 145
# Maxlen for example   274: 129
# Maxlen for example   275: 180
# Maxlen for example   276: 325
# Maxlen for example   277: 140
# Maxlen for example   278: 329
# Maxlen for example   279: 193
# Maxlen for example   280: 184
# Maxlen for example   281: 301
# Maxlen for example   282: 145
# Maxlen for example   283: 246
# Maxlen for example   284: 209
# Maxlen for example   285: 179
# Maxlen for example   286: 317
# Maxlen for example   287: 172
# Maxlen for example   288: 125
# Maxlen for example   289: 115
# Maxlen for example   290: 187
# Maxlen for example   291: 308
# Maxlen for example   292: 212
# Maxlen for example   293: 152
# Maxlen for example   294: 185
# Maxlen for example   295: 194
# Maxlen for example   296: 181
# Maxlen for example   297: 190
# Maxlen for example   298: 273
# Maxlen for example   299: 201
# Maxlen for example   300: 191
# Maxlen for example   301: 140
# Maxlen for example   302: 141
# Maxlen for example   303: 121
# Maxlen for example   304: 126
# Maxlen for example   305: 156
# Maxlen for example   306: 149
# Maxlen for example   307: 117
# Maxlen for example   308: 145
# Maxlen for example   309: 193
# Maxlen for example   310: 120
# Maxlen for example   311: 145
# Maxlen for example   312: 153
# Maxlen for example   313: 155
# Maxlen for example   314: 112
# Maxlen for example   315: 123
# Maxlen for example   316: 143
# Maxlen for example   317: 205
# Maxlen for example   318: 126
# Maxlen for example   319: 213
# Maxlen for example   320: 160
# Maxlen for example   321: 145
# Maxlen for example   322: 323
# Maxlen for example   323: 231
# Maxlen for example   324: 177
# Maxlen for example   325: 272
# Maxlen for example   326: 231
# Maxlen for example   327: 298
# Maxlen for example   328: 293
# Maxlen for example   329: 124
# Maxlen for example   330: 139
# Maxlen for example   331: 177
# Maxlen for example   332: 317
# Maxlen for example   333: 273
# Maxlen for example   334: 254
# Maxlen for example   335: 118
# Maxlen for example   336: 192
# Maxlen for example   337: 165
# Maxlen for example   338: 257
# Maxlen for example   339: 294
# Maxlen for example   340: 118
# Maxlen for example   341: 154
# Maxlen for example   342: 139
# Maxlen for example   343: 186
# Maxlen for example   344: 184
# Maxlen for example   345: 138
# Maxlen for example   346: 153
# Maxlen for example   347: 341
# Maxlen for example   348: 142
# Maxlen for example   349: 146
# Maxlen for example   350: 177
# Maxlen for example   351: 183
# Maxlen for example   352: 131
# Maxlen for example   353: 144
# Maxlen for example   354: 235
# Maxlen for example   355: 190
# Maxlen for example   356: 237
# Maxlen for example   357: 285
# Maxlen for example   358: 147
# Maxlen for example   359: 263
# Maxlen for example   360: 329
# Maxlen for example   361: 283
# Maxlen for example   362: 131
# Maxlen for example   363: 125
# Maxlen for example   364: 209
# Maxlen for example   365: 132
# Maxlen for example   366: 207
# Maxlen for example   367: 128
# Maxlen for example   368: 145
# Maxlen for example   369: 118
# Maxlen for example   370: 288
# Maxlen for example   371: 174
# Maxlen for example   372: 219
# Maxlen for example   373: 128
# Maxlen for example   374: 117
# Maxlen for example   375: 117
# Maxlen for example   376: 324
# Maxlen for example   377: 170
# Maxlen for example   378: 223
# Maxlen for example   379: 187
# Maxlen for example   380: 348
# Maxlen for example   381: 144
# Maxlen for example   382: 123
# Maxlen for example   383: 196
# Maxlen for example   384: 225
# Maxlen for example   385: 142
# Maxlen for example   386: 120
# Maxlen for example   387: 126
# Maxlen for example   388: 254
# Maxlen for example   389: 201
# Maxlen for example   390: 113
# Maxlen for example   391: 326
# Maxlen for example   392: 188
# Maxlen for example   393: 155
# Maxlen for example   394: 277
# Maxlen for example   395: 116
# Maxlen for example   396: 122
# Maxlen for example   397: 134
# Maxlen for example   398: 287
# Maxlen for example   399: 131
# Maxlen for example   400: 213
# Maxlen for example   401: 122
# Maxlen for example   402: 207
# Maxlen for example   403: 144
# Maxlen for example   404: 141
# Maxlen for example   405: 118
# Maxlen for example   406: 185
# Maxlen for example   407: 342
# Maxlen for example   408: 288
# Maxlen for example   409: 285
# Maxlen for example   410: 137
# Maxlen for example   411: 197
# Maxlen for example   412: 193
# Maxlen for example   413: 158
# Maxlen for example   414: 119
# Maxlen for example   415: 132
# Maxlen for example   416: 122
# Maxlen for example   417: 205
# Maxlen for example   418: 277
# Maxlen for example   419: 158
# Maxlen for example   420: 135
# Maxlen for example   421: 127
# Maxlen for example   422: 223
# Maxlen for example   423: 307
# Maxlen for example   424: 170
# Maxlen for example   425: 343
# Maxlen for example   426: 168
# Maxlen for example   427: 276
# Maxlen for example   428: 161
# Maxlen for example   429: 127
# Maxlen for example   430: 198
# Maxlen for example   431: 156
# Maxlen for example   432: 121
# Maxlen for example   433: 121
# Maxlen for example   434: 133
# Maxlen for example   435: 158
# Maxlen for example   436: 310
# Maxlen for example   437: 171
# Maxlen for example   438: 197
# Maxlen for example   439: 203
# Maxlen for example   440: 272
# Maxlen for example   441: 184
# Maxlen for example   442: 124
# Maxlen for example   443: 113
# Maxlen for example   444: 241
# Maxlen for example   445: 173
# Maxlen for example   446: 237
# Maxlen for example   447: 135
# Maxlen for example   448: 128
# Maxlen for example   449: 166
# Maxlen for example   450: 257
# Maxlen for example   451: 138
# Maxlen for example   452: 129
# Maxlen for example   453: 120
# Maxlen for example   454: 187
# Maxlen for example   455: 156
# Maxlen for example   456: 137
# Maxlen for example   457: 270
# Maxlen for example   458: 176
# Maxlen for example   459: 120
# Maxlen for example   460: 304
# Maxlen for example   461: 150
# Maxlen for example   462: 128
# Maxlen for example   463: 269
# Maxlen for example   464: 163
# Maxlen for example   465: 210
# Maxlen for example   466: 187
# Maxlen for example   467: 303
# Maxlen for example   468: 161
# Maxlen for example   469: 169
# Maxlen for example   470: 150
# Maxlen for example   471: 271
# Maxlen for example   472: 211
# Maxlen for example   473: 203
# Maxlen for example   474: 112
# Maxlen for example   475: 128
# Maxlen for example   476: 269
# Maxlen for example   477: 115
# Maxlen for example   478: 129
# Maxlen for example   479: 194
# Maxlen for example   480: 124
# Maxlen for example   481: 124
# Maxlen for example   482: 178
# Maxlen for example   483: 284
# Maxlen for example   484: 147
# Maxlen for example   485: 195
# Maxlen for example   486: 148
# Maxlen for example   487: 222
# Maxlen for example   488: 121
# Maxlen for example   489: 305
# Maxlen for example   490: 163
# Maxlen for example   491: 134
# Maxlen for example   492: 283
# Maxlen for example   493: 211
# Maxlen for example   494: 175
# Maxlen for example   495: 236
# Maxlen for example   496: 141
# Maxlen for example   497: 130
# Maxlen for example   498: 136
# Maxlen for example   499: 119
# Maxlen for example   500: 143
# Maxlen for example   501: 314
# Maxlen for example   502: 171
# Maxlen for example   503: 293
# Maxlen for example   504: 174
# Maxlen for example   505: 121
# Maxlen for example   506: 270
# Maxlen for example   507: 136
# Maxlen for example   508: 136
# Maxlen for example   509: 116
# Maxlen for example   510: 193
# Maxlen for example   511: 219
# Maxlen for example   512: 239
# Maxlen for example   513: 139
# Maxlen for example   514: 270
# Maxlen for example   515: 139
# Maxlen for example   516: 200
# Maxlen for example   517: 204
# Maxlen for example   518: 177
# Maxlen for example   519: 145
# Maxlen for example   520: 138
# Maxlen for example   521: 145
# Maxlen for example   522: 307
# Maxlen for example   523: 193
# Maxlen for example   524: 145
# Maxlen for example   525: 132
# Maxlen for example   526: 257
# Maxlen for example   527: 254
# Maxlen for example   528: 192
# Maxlen for example   529: 175
# Maxlen for example   530: 203
# Maxlen for example   531: 136
# Maxlen for example   532: 125
# Maxlen for example   533: 170
# Maxlen for example   534: 196
# Maxlen for example   535: 342
# Maxlen for example   536: 120
# Maxlen for example   537: 157
# Maxlen for example   538: 182
# Maxlen for example   539: 312
# Maxlen for example   540: 161
# Maxlen for example   541: 161
# Maxlen for example   542: 144
# Maxlen for example   543: 339
# Maxlen for example   544: 190
# Maxlen for example   545: 203
# Maxlen for example   546: 221
# Maxlen for example   547: 119
# Maxlen for example   548: 143
# Maxlen for example   549: 266
# Maxlen for example   550: 117
# Maxlen for example   551: 118
# Maxlen for example   552: 200
# Maxlen for example   553: 120
# Maxlen for example   554: 192
# Maxlen for example   555: 188
# Maxlen for example   556: 162
# Maxlen for example   557: 121
# Maxlen for example   558: 199
# Maxlen for example   559: 184
# Maxlen for example   560: 214
# Maxlen for example   561: 275
# Maxlen for example   562: 231
# Maxlen for example   563: 119
# Maxlen for example   564: 115
# Maxlen for example   565: 173
# Maxlen for example   566: 208
# Maxlen for example   567: 159
# Maxlen for example   568: 146
# Maxlen for example   569: 141
# Maxlen for example   570: 123
# Maxlen for example   571: 148
# Maxlen for example   572: 128
# Maxlen for example   573: 161
# Maxlen for example   574: 202
# Maxlen for example   575: 150
# Maxlen for example   576: 117
# Maxlen for example   577: 209
# Maxlen for example   578: 142
# Maxlen for example   579: 111
# Maxlen for example   580: 178
# Maxlen for example   581: 116
# Maxlen for example   582: 136
# Maxlen for example   583: 191
# Maxlen for example   584: 138
# Maxlen for example   585: 119
# Maxlen for example   586: 247
# Maxlen for example   587: 182
# Maxlen for example   588: 159
# Maxlen for example   589: 151
# Maxlen for example   590: 146
# Maxlen for example   591: 244
# Maxlen for example   592: 175
# Maxlen for example   593: 140
# Maxlen for example   594: 202
# Maxlen for example   595: 120
# Maxlen for example   596: 279
# Maxlen for example   597: 261
# Maxlen for example   598: 333
# Maxlen for example   599: 179
# Maxlen for example   600: 155
# Maxlen for example   601: 130
# Maxlen for example   602: 123
# Maxlen for example   603: 154
# Maxlen for example   604: 169
# Maxlen for example   605: 143
# Maxlen for example   606: 131
# Maxlen for example   607: 282
# Maxlen for example   608: 200
# Maxlen for example   609: 130
# Maxlen for example   610: 134
# Maxlen for example   611: 151
# Maxlen for example   612: 118
# Maxlen for example   613: 127
# Maxlen for example   614: 116
# Maxlen for example   615: 176
# Maxlen for example   616: 198
# Maxlen for example   617: 151
# Maxlen for example   618: 163
# Maxlen for example   619: 141
# Maxlen for example   620: 279
# Maxlen for example   621: 157
# Maxlen for example   622: 314
# Maxlen for example   623: 124
# Maxlen for example   624: 244
# Maxlen for example   625: 137
# Maxlen for example   626: 177
# Maxlen for example   627: 150
# Maxlen for example   628: 164
# Maxlen for example   629: 123
# Maxlen for example   630: 215
# Maxlen for example   631: 155
# Maxlen for example   632: 170
# Maxlen for example   633: 232
# Maxlen for example   634: 127
# Maxlen for example   635: 134
# Maxlen for example   636: 364
# Maxlen for example   637: 158
# Maxlen for example   638: 144
# Maxlen for example   639: 179
# Maxlen for example   640: 129
# Maxlen for example   641: 232
# Maxlen for example   642: 135
# Maxlen for example   643: 165
# Maxlen for example   644: 165
# Maxlen for example   645: 174
# Maxlen for example   646: 294
# Maxlen for example   647: 117
# Maxlen for example   648: 162
# Maxlen for example   649: 182
# Maxlen for example   650: 137
# Maxlen for example   651: 145
# Maxlen for example   652: 301
# Maxlen for example   653: 117
# Maxlen for example   654: 185
# Maxlen for example   655: 183
# Maxlen for example   656: 118
# Maxlen for example   657: 185
# Maxlen for example   658: 302
# Maxlen for example   659: 248
# Maxlen for example   660: 132
# Maxlen for example   661: 114
# Maxlen for example   662: 160
# Maxlen for example   663: 186
# Maxlen for example   664: 116
# Maxlen for example   665: 115
# Maxlen for example   666: 126
# Maxlen for example   667: 252
# Maxlen for example   668: 221
# Maxlen for example   669: 211
# Maxlen for example   670: 280
# Maxlen for example   671: 150
# Maxlen for example   672: 142
# Maxlen for example   673: 314
# Maxlen for example   674: 209
# Maxlen for example   675: 182
# Maxlen for example   676: 211
# Maxlen for example   677: 183
# Maxlen for example   678: 142
# Maxlen for example   679: 122
# Maxlen for example   680: 202
# Maxlen for example   681: 296
# Maxlen for example   682: 168
# Maxlen for example   683: 170
# Maxlen for example   684: 330
# Maxlen for example   685: 305
# Maxlen for example   686: 228
# Maxlen for example   687: 123
# Maxlen for example   688: 118
# Maxlen for example   689: 144
# Maxlen for example   690: 120
# Maxlen for example   691: 218
# Maxlen for example   692: 161
# Maxlen for example   693: 205
# Maxlen for example   694: 236
# Maxlen for example   695: 178
# Maxlen for example   696: 123
# Maxlen for example   697: 294
# Maxlen for example   698: 124
# Maxlen for example   699: 192
# Maxlen for example   700: 137
# Maxlen for example   701: 216
# Maxlen for example   702: 154
# Maxlen for example   703: 183
# Maxlen for example   704: 282
# Maxlen for example   705: 147
# Maxlen for example   706: 255
# Maxlen for example   707: 133
# Maxlen for example   708: 214
# Maxlen for example   709: 217
# Maxlen for example   710: 128
# Maxlen for example   711: 201
# Maxlen for example   712: 296
# Maxlen for example   713: 129
# Maxlen for example   714: 197
# Maxlen for example   715: 306
# Maxlen for example   716: 214
# Maxlen for example   717: 113
# Maxlen for example   718: 156
# Maxlen for example   719: 150
# Maxlen for example   720: 314
# Maxlen for example   721: 176
# Maxlen for example   722: 139
# Maxlen for example   723: 111
# Maxlen for example   724: 194
# Maxlen for example   725: 119
# Maxlen for example   726: 119
# Maxlen for example   727: 207
# Maxlen for example   728: 193
# Maxlen for example   729: 157
# Maxlen for example   730: 136
# Maxlen for example   731: 212
# Maxlen for example   732: 178
# Maxlen for example   733: 156
# Maxlen for example   734: 263
# Maxlen for example   735: 189
# Maxlen for example   736: 124
# Maxlen for example   737: 165
# Maxlen for example   738: 233
# Maxlen for example   739: 237
# Maxlen for example   740: 139
# Maxlen for example   741: 122
# Maxlen for example   742: 188
# Maxlen for example   743: 170
# Maxlen for example   744: 196
# Maxlen for example   745: 164
# Maxlen for example   746: 250
# Maxlen for example   747: 148
# Maxlen for example   748: 181
# Maxlen for example   749: 203
# Maxlen for example   750: 230
# Maxlen for example   751: 132
# Maxlen for example   752: 123
# Maxlen for example   753: 195
# Maxlen for example   754: 134
# Maxlen for example   755: 122
# Maxlen for example   756: 118
# Maxlen for example   757: 106
# Maxlen for example   758: 192
# Maxlen for example   759: 140
# Maxlen for example   760: 124
# Maxlen for example   761: 293
# Maxlen for example   762: 123
# Maxlen for example   763: 141
# Maxlen for example   764: 228
# Maxlen for example   765: 163
# Maxlen for example   766: 286
# Maxlen for example   767: 323
# Maxlen for example   768: 196
# Maxlen for example   769: 192
# Maxlen for example   770: 187
# Maxlen for example   771: 204
# Maxlen for example   772: 122
# Maxlen for example   773: 242
# Maxlen for example   774: 132
# Maxlen for example   775: 276
# Maxlen for example   776: 170
# Maxlen for example   777: 239
# Maxlen for example   778: 164
# Maxlen for example   779: 141
# Maxlen for example   780: 193
# Maxlen for example   781: 179
# Maxlen for example   782: 293
# Maxlen for example   783: 295
# Maxlen for example   784: 147
# Maxlen for example   785: 197
# Maxlen for example   786: 128
# Maxlen for example   787: 154
# Maxlen for example   788: 135
# Maxlen for example   789: 127
# Maxlen for example   790: 246
# Maxlen for example   791: 198
# Maxlen for example   792: 182
# Maxlen for example   793: 274
# Maxlen for example   794: 212
# Maxlen for example   795: 231
# Maxlen for example   796: 154
# Maxlen for example   797: 195
# Maxlen for example   798: 156
# Maxlen for example   799: 143
# Maxlen for example   800: 176
# Maxlen for example   801: 143
# Maxlen for example   802: 192
# Maxlen for example   803: 153
# Maxlen for example   804: 161
# Maxlen for example   805: 244
# Maxlen for example   806: 223
# Maxlen for example   807: 183
# Maxlen for example   808: 205
# Maxlen for example   809: 163
# Maxlen for example   810: 153
# Maxlen for example   811: 168
# Maxlen for example   812: 243
# Maxlen for example   813: 268
# Maxlen for example   814: 276
# Maxlen for example   815: 184
# Maxlen for example   816: 180
# Maxlen for example   817: 186
# Maxlen for example   818: 200
# Maxlen for example   819: 275
# Maxlen for example   820: 123
# Maxlen for example   821: 233
# Maxlen for example   822: 220
# Maxlen for example   823: 308
# Maxlen for example   824: 143
# Maxlen for example   825: 188
# Maxlen for example   826: 119
# Maxlen for example   827: 112
# Maxlen for example   828: 133
# Maxlen for example   829: 200
# Maxlen for example   830: 247
# Maxlen for example   831: 159
# Maxlen for example   832: 138
# Maxlen for example   833: 144
# Maxlen for example   834: 181
# Maxlen for example   835: 125
# Maxlen for example   836: 133
# Maxlen for example   837: 184
# Maxlen for example   838: 202
# Maxlen for example   839: 120
# Maxlen for example   840: 275
# Maxlen for example   841: 122
# Maxlen for example   842: 218
# Maxlen for example   843: 121
# Maxlen for example   844: 177
# Maxlen for example   845: 354
# Maxlen for example   846: 192
# Maxlen for example   847: 122
# Maxlen for example   848: 178
# Maxlen for example   849: 129
# Maxlen for example   850: 121
# Maxlen for example   851: 269
# Maxlen for example   852: 140
# Maxlen for example   853: 181
# Maxlen for example   854: 207
# Maxlen for example   855: 190
# Maxlen for example   856: 147
# Maxlen for example   857: 249
# Maxlen for example   858: 131
# Maxlen for example   859: 190
# Maxlen for example   860: 270
# Maxlen for example   861: 198
# Maxlen for example   862: 194
# Maxlen for example   863: 192
# Maxlen for example   864: 200
# Maxlen for example   865: 124
# Maxlen for example   866: 323
# Maxlen for example   867: 243
# Maxlen for example   868: 122
# Maxlen for example   869: 213
# Maxlen for example   870: 131
# Maxlen for example   871: 162
# Maxlen for example   872: 127
# Maxlen for example   873: 152
# Maxlen for example   874: 187
# Maxlen for example   875: 160
# Maxlen for example   876: 127
# Maxlen for example   877: 129
# Maxlen for example   878: 222
# Maxlen for example   879: 309
# Maxlen for example   880: 335
# Maxlen for example   881: 132
# Maxlen for example   882: 134
# Maxlen for example   883: 183
# Maxlen for example   884: 126
# Maxlen for example   885: 312
# Maxlen for example   886: 118
# Maxlen for example   887: 155
# Maxlen for example   888: 141
# Maxlen for example   889: 237
# Maxlen for example   890: 139
# Maxlen for example   891: 195
# Maxlen for example   892: 224
# Maxlen for example   893: 320
# Maxlen for example   894: 228
# Maxlen for example   895: 130
# Maxlen for example   896: 148
# Maxlen for example   897: 226
# Maxlen for example   898: 180
# Maxlen for example   899: 169
# Maxlen for example   900: 127
# Maxlen for example   901: 243
# Maxlen for example   902: 246
# Maxlen for example   903: 256
# Maxlen for example   904: 310
# Maxlen for example   905: 252
# Maxlen for example   906: 198
# Maxlen for example   907: 157
# Maxlen for example   908: 125
# Maxlen for example   909: 118
# Maxlen for example   910: 188
# Maxlen for example   911: 162
# Maxlen for example   912: 277
# Maxlen for example   913: 209
# Maxlen for example   914: 182
# Maxlen for example   915: 122
# Maxlen for example   916: 123
# Maxlen for example   917: 258
# Maxlen for example   918: 170
# Maxlen for example   919: 115
# Maxlen for example   920: 185
# Maxlen for example   921: 232
# Maxlen for example   922: 117
# Maxlen for example   923: 198
# Maxlen for example   924: 152
# Maxlen for example   925: 139
# Maxlen for example   926: 189
# Maxlen for example   927: 340
# Maxlen for example   928: 182
# Maxlen for example   929: 189
# Maxlen for example   930: 129
# Maxlen for example   931: 136
# Maxlen for example   932: 119
# Maxlen for example   933: 151
# Maxlen for example   934: 234
# Maxlen for example   935: 120
# Maxlen for example   936: 217
# Maxlen for example   937: 314
# Maxlen for example   938: 132
# Maxlen for example   939: 120
# Maxlen for example   940: 227
# Maxlen for example   941: 191
# Maxlen for example   942: 332
# Maxlen for example   943: 199
# Maxlen for example   944: 249
# Maxlen for example   945: 166
# Maxlen for example   946: 158
# Maxlen for example   947: 141
# Maxlen for example   948: 121
# Maxlen for example   949: 375
# Maxlen for example   950: 136
# Maxlen for example   951: 185
# Maxlen for example   952: 122
# Maxlen for example   953: 206
# Maxlen for example   954: 146
# Maxlen for example   955: 127
# Maxlen for example   956: 130
# Maxlen for example   957: 148
# Maxlen for example   958: 136
# Maxlen for example   959: 182
# Maxlen for example   960: 232
# Maxlen for example   961: 287
# Maxlen for example   962: 171
# Maxlen for example   963: 166
# Maxlen for example   964: 138
# Maxlen for example   965: 256
# Maxlen for example   966: 175
# Maxlen for example   967: 227
# Maxlen for example   968: 201
# Maxlen for example   969: 114
# Maxlen for example   970: 122
# Maxlen for example   971: 124
# Maxlen for example   972: 277
# Maxlen for example   973: 134
# Maxlen for example   974: 124
# Maxlen for example   975: 204
# Maxlen for example   976: 125
# Maxlen for example   977: 292
# Maxlen for example   978: 147
# Maxlen for example   979: 138
# Maxlen for example   980: 139
# Maxlen for example   981: 274
# Maxlen for example   982: 189
# Maxlen for example   983: 138
# Maxlen for example   984: 160
# Maxlen for example   985: 206
# Maxlen for example   986: 150
# Maxlen for example   987: 122
# Maxlen for example   988: 294
# Maxlen for example   989: 192
# Maxlen for example   990: 218
# Maxlen for example   991: 194
# Maxlen for example   992: 136
# Maxlen for example   993: 229
# Maxlen for example   994: 175
# Maxlen for example   995: 196
# Maxlen for example   996: 212
# Maxlen for example   997: 279
# Maxlen for example   998: 255
# Maxlen for example   999: 137
# Maxlen for example  1000: 116
# All maxlen: 375

# %%
all_maxlen = 0
for i, cd in enumerate(test_data):
    fields = flatten_fields(cd)
    maxlen = 0
    for f in fields:
        tokens = tokenizer(f, return_tensors='pt', padding=True)
        maxlen = max(maxlen, tokens['input_ids'].shape[1])
    print(f'Maxlen for example {i+1:5}: {maxlen}')
    all_maxlen = max(all_maxlen, maxlen)

print(f'All maxlen: {all_maxlen}')
# Out:
# Maxlen for example     1: 118
# Maxlen for example     2: 125
# Maxlen for example     3: 168
# Maxlen for example     4: 254
# Maxlen for example     5: 120
# Maxlen for example     6: 186
# Maxlen for example     7: 198
# Maxlen for example     8: 126
# Maxlen for example     9: 175
# Maxlen for example    10: 119
# Maxlen for example    11: 186
# Maxlen for example    12: 239
# Maxlen for example    13: 297
# Maxlen for example    14: 171
# Maxlen for example    15: 129
# Maxlen for example    16: 124
# Maxlen for example    17: 192
# Maxlen for example    18: 141
# Maxlen for example    19: 185
# Maxlen for example    20: 186
# Maxlen for example    21: 188
# Maxlen for example    22: 135
# Maxlen for example    23: 282
# Maxlen for example    24: 297
# Maxlen for example    25: 184
# Maxlen for example    26: 302
# Maxlen for example    27: 236
# Maxlen for example    28: 174
# Maxlen for example    29: 308
# Maxlen for example    30: 218
# Maxlen for example    31: 158
# Maxlen for example    32: 359
# Maxlen for example    33: 223
# Maxlen for example    34: 256
# Maxlen for example    35: 124
# Maxlen for example    36: 161
# Maxlen for example    37: 201
# Maxlen for example    38: 191
# Maxlen for example    39: 133
# Maxlen for example    40: 124
# Maxlen for example    41: 163
# Maxlen for example    42: 120
# Maxlen for example    43: 282
# Maxlen for example    44: 118
# Maxlen for example    45: 286
# Maxlen for example    46: 280
# Maxlen for example    47: 297
# Maxlen for example    48: 131
# Maxlen for example    49: 197
# Maxlen for example    50: 117
# Maxlen for example    51: 118
# Maxlen for example    52: 130
# Maxlen for example    53: 121
# Maxlen for example    54: 290
# Maxlen for example    55: 144
# Maxlen for example    56: 144
# Maxlen for example    57: 331
# Maxlen for example    58: 128
# Maxlen for example    59: 184
# Maxlen for example    60: 370
# Maxlen for example    61: 141
# Maxlen for example    62: 159
# Maxlen for example    63: 290
# Maxlen for example    64: 193
# Maxlen for example    65: 120
# Maxlen for example    66: 140
# Maxlen for example    67: 252
# Maxlen for example    68: 138
# Maxlen for example    69: 157
# Maxlen for example    70: 192
# Maxlen for example    71: 156
# Maxlen for example    72: 154
# Maxlen for example    73: 240
# Maxlen for example    74: 168
# Maxlen for example    75: 139
# Maxlen for example    76: 197
# Maxlen for example    77: 199
# Maxlen for example    78: 114
# Maxlen for example    79: 112
# Maxlen for example    80: 125
# Maxlen for example    81: 201
# Maxlen for example    82: 198
# Maxlen for example    83: 158
# Maxlen for example    84: 189
# Maxlen for example    85: 282
# Maxlen for example    86: 207
# Maxlen for example    87: 180
# Maxlen for example    88: 320
# Maxlen for example    89: 119
# Maxlen for example    90: 126
# Maxlen for example    91: 132
# Maxlen for example    92: 239
# Maxlen for example    93: 179
# Maxlen for example    94: 266
# Maxlen for example    95: 296
# Maxlen for example    96: 221
# Maxlen for example    97: 228
# Maxlen for example    98: 224
# Maxlen for example    99: 218
# Maxlen for example   100: 133
# Maxlen for example   101: 160
# Maxlen for example   102: 176
# Maxlen for example   103: 119
# Maxlen for example   104: 135
# Maxlen for example   105: 172
# Maxlen for example   106: 252
# Maxlen for example   107: 119
# Maxlen for example   108: 146
# Maxlen for example   109: 144
# Maxlen for example   110: 136
# Maxlen for example   111: 192
# Maxlen for example   112: 189
# Maxlen for example   113: 179
# Maxlen for example   114: 124
# Maxlen for example   115: 145
# Maxlen for example   116: 161
# Maxlen for example   117: 200
# Maxlen for example   118: 238
# Maxlen for example   119: 297
# Maxlen for example   120: 242
# Maxlen for example   121: 144
# Maxlen for example   122: 124
# Maxlen for example   123: 281
# Maxlen for example   124: 194
# Maxlen for example   125: 163
# Maxlen for example   126: 126
# Maxlen for example   127: 197
# Maxlen for example   128: 186
# Maxlen for example   129: 120
# Maxlen for example   130: 196
# Maxlen for example   131: 113
# Maxlen for example   132: 148
# Maxlen for example   133: 227
# Maxlen for example   134: 246
# Maxlen for example   135: 151
# Maxlen for example   136: 131
# Maxlen for example   137: 131
# Maxlen for example   138: 136
# Maxlen for example   139: 136
# Maxlen for example   140: 174
# Maxlen for example   141: 169
# Maxlen for example   142: 144
# Maxlen for example   143: 178
# Maxlen for example   144: 202
# Maxlen for example   145: 147
# Maxlen for example   146: 174
# Maxlen for example   147: 127
# Maxlen for example   148: 151
# Maxlen for example   149: 217
# Maxlen for example   150: 117
# Maxlen for example   151: 223
# Maxlen for example   152: 300
# Maxlen for example   153: 261
# Maxlen for example   154: 128
# Maxlen for example   155: 130
# Maxlen for example   156: 168
# Maxlen for example   157: 257
# Maxlen for example   158: 188
# Maxlen for example   159: 118
# Maxlen for example   160: 146
# Maxlen for example   161: 167
# Maxlen for example   162: 265
# Maxlen for example   163: 267
# Maxlen for example   164: 133
# Maxlen for example   165: 176
# Maxlen for example   166: 208
# Maxlen for example   167: 221
# Maxlen for example   168: 196
# Maxlen for example   169: 124
# Maxlen for example   170: 199
# Maxlen for example   171: 197
# Maxlen for example   172: 139
# Maxlen for example   173: 147
# Maxlen for example   174: 334
# Maxlen for example   175: 187
# Maxlen for example   176: 287
# Maxlen for example   177: 119
# Maxlen for example   178: 172
# Maxlen for example   179: 264
# Maxlen for example   180: 133
# Maxlen for example   181: 247
# Maxlen for example   182: 330
# Maxlen for example   183: 273
# Maxlen for example   184: 275
# Maxlen for example   185: 198
# Maxlen for example   186: 275
# Maxlen for example   187: 216
# Maxlen for example   188: 303
# Maxlen for example   189: 143
# Maxlen for example   190: 292
# Maxlen for example   191: 141
# Maxlen for example   192: 138
# Maxlen for example   193: 168
# Maxlen for example   194: 254
# Maxlen for example   195: 176
# Maxlen for example   196: 144
# Maxlen for example   197: 204
# Maxlen for example   198: 222
# Maxlen for example   199: 147
# Maxlen for example   200: 124
# Maxlen for example   201: 197
# Maxlen for example   202: 208
# Maxlen for example   203: 121
# Maxlen for example   204: 215
# Maxlen for example   205: 240
# Maxlen for example   206: 218
# Maxlen for example   207: 170
# Maxlen for example   208: 150
# Maxlen for example   209: 221
# Maxlen for example   210: 242
# Maxlen for example   211: 251
# Maxlen for example   212: 144
# Maxlen for example   213: 340
# Maxlen for example   214: 133
# Maxlen for example   215: 123
# Maxlen for example   216: 184
# Maxlen for example   217: 330
# Maxlen for example   218: 127
# Maxlen for example   219: 144
# Maxlen for example   220: 182
# Maxlen for example   221: 182
# Maxlen for example   222: 160
# Maxlen for example   223: 148
# Maxlen for example   224: 128
# Maxlen for example   225: 203
# Maxlen for example   226: 126
# Maxlen for example   227: 121
# Maxlen for example   228: 255
# Maxlen for example   229: 155
# Maxlen for example   230: 184
# Maxlen for example   231: 172
# Maxlen for example   232: 178
# Maxlen for example   233: 185
# Maxlen for example   234: 286
# Maxlen for example   235: 173
# Maxlen for example   236: 121
# Maxlen for example   237: 207
# Maxlen for example   238: 130
# Maxlen for example   239: 251
# Maxlen for example   240: 257
# Maxlen for example   241: 146
# Maxlen for example   242: 295
# Maxlen for example   243: 224
# Maxlen for example   244: 264
# Maxlen for example   245: 307
# Maxlen for example   246: 118
# Maxlen for example   247: 142
# Maxlen for example   248: 181
# Maxlen for example   249: 289
# Maxlen for example   250: 177
# Maxlen for example   251: 213
# Maxlen for example   252: 257
# Maxlen for example   253: 124
# Maxlen for example   254: 246
# Maxlen for example   255: 166
# Maxlen for example   256: 146
# Maxlen for example   257: 255
# Maxlen for example   258: 179
# Maxlen for example   259: 132
# Maxlen for example   260: 123
# Maxlen for example   261: 245
# Maxlen for example   262: 114
# Maxlen for example   263: 157
# Maxlen for example   264: 115
# Maxlen for example   265: 213
# Maxlen for example   266: 147
# Maxlen for example   267: 118
# Maxlen for example   268: 132
# Maxlen for example   269: 155
# Maxlen for example   270: 251
# Maxlen for example   271: 307
# Maxlen for example   272: 296
# Maxlen for example   273: 196
# Maxlen for example   274: 212
# Maxlen for example   275: 367
# Maxlen for example   276: 123
# Maxlen for example   277: 190
# Maxlen for example   278: 187
# Maxlen for example   279: 146
# Maxlen for example   280: 126
# Maxlen for example   281: 180
# Maxlen for example   282: 183
# Maxlen for example   283: 105
# Maxlen for example   284: 204
# Maxlen for example   285: 133
# Maxlen for example   286: 122
# Maxlen for example   287: 187
# Maxlen for example   288: 198
# Maxlen for example   289: 159
# Maxlen for example   290: 334
# Maxlen for example   291: 258
# Maxlen for example   292: 135
# Maxlen for example   293: 129
# Maxlen for example   294: 172
# Maxlen for example   295: 309
# Maxlen for example   296: 148
# Maxlen for example   297: 127
# Maxlen for example   298: 233
# Maxlen for example   299: 289
# Maxlen for example   300: 205
# Maxlen for example   301: 189
# Maxlen for example   302: 204
# Maxlen for example   303: 224
# Maxlen for example   304: 284
# Maxlen for example   305: 147
# Maxlen for example   306: 252
# Maxlen for example   307: 200
# Maxlen for example   308: 190
# Maxlen for example   309: 260
# Maxlen for example   310: 198
# Maxlen for example   311: 296
# Maxlen for example   312: 130
# Maxlen for example   313: 171
# Maxlen for example   314: 192
# Maxlen for example   315: 194
# Maxlen for example   316: 210
# Maxlen for example   317: 272
# Maxlen for example   318: 205
# Maxlen for example   319: 142
# Maxlen for example   320: 166
# Maxlen for example   321: 187
# Maxlen for example   322: 141
# Maxlen for example   323: 174
# Maxlen for example   324: 123
# Maxlen for example   325: 119
# Maxlen for example   326: 141
# Maxlen for example   327: 117
# Maxlen for example   328: 181
# Maxlen for example   329: 305
# Maxlen for example   330: 121
# Maxlen for example   331: 173
# Maxlen for example   332: 121
# Maxlen for example   333: 176
# Maxlen for example   334: 141
# Maxlen for example   335: 115
# Maxlen for example   336: 199
# Maxlen for example   337: 195
# Maxlen for example   338: 128
# Maxlen for example   339: 272
# Maxlen for example   340: 139
# Maxlen for example   341: 159
# Maxlen for example   342: 217
# Maxlen for example   343: 310
# Maxlen for example   344: 121
# Maxlen for example   345: 140
# Maxlen for example   346: 134
# Maxlen for example   347: 158
# Maxlen for example   348: 179
# Maxlen for example   349: 155
# Maxlen for example   350: 114
# Maxlen for example   351: 140
# Maxlen for example   352: 118
# Maxlen for example   353: 268
# Maxlen for example   354: 298
# Maxlen for example   355: 178
# Maxlen for example   356: 284
# Maxlen for example   357: 182
# Maxlen for example   358: 213
# Maxlen for example   359: 354
# Maxlen for example   360: 122
# Maxlen for example   361: 128
# Maxlen for example   362: 137
# Maxlen for example   363: 298
# Maxlen for example   364: 148
# Maxlen for example   365: 308
# Maxlen for example   366: 365
# Maxlen for example   367: 111
# Maxlen for example   368: 139
# Maxlen for example   369: 126
# Maxlen for example   370: 146
# Maxlen for example   371: 177
# Maxlen for example   372: 223
# Maxlen for example   373: 127
# Maxlen for example   374: 127
# Maxlen for example   375: 124
# Maxlen for example   376: 114
# Maxlen for example   377: 113
# Maxlen for example   378: 195
# Maxlen for example   379: 190
# Maxlen for example   380: 126
# Maxlen for example   381: 172
# Maxlen for example   382: 208
# Maxlen for example   383: 267
# Maxlen for example   384: 269
# Maxlen for example   385: 130
# Maxlen for example   386: 125
# Maxlen for example   387: 268
# Maxlen for example   388: 181
# Maxlen for example   389: 306
# Maxlen for example   390: 275
# Maxlen for example   391: 178
# Maxlen for example   392: 195
# Maxlen for example   393: 196
# Maxlen for example   394: 189
# Maxlen for example   395: 185
# Maxlen for example   396: 180
# Maxlen for example   397: 141
# Maxlen for example   398: 292
# Maxlen for example   399: 124
# Maxlen for example   400: 113
# Maxlen for example   401: 115
# Maxlen for example   402: 161
# Maxlen for example   403: 134
# Maxlen for example   404: 144
# Maxlen for example   405: 144
# Maxlen for example   406: 242
# Maxlen for example   407: 256
# Maxlen for example   408: 252
# Maxlen for example   409: 206
# Maxlen for example   410: 211
# Maxlen for example   411: 223
# Maxlen for example   412: 314
# Maxlen for example   413: 198
# Maxlen for example   414: 141
# Maxlen for example   415: 116
# Maxlen for example   416: 125
# Maxlen for example   417: 145
# Maxlen for example   418: 173
# Maxlen for example   419: 296
# Maxlen for example   420: 238
# Maxlen for example   421: 125
# Maxlen for example   422: 152
# Maxlen for example   423: 180
# Maxlen for example   424: 184
# Maxlen for example   425: 220
# Maxlen for example   426: 116
# Maxlen for example   427: 310
# Maxlen for example   428: 111
# Maxlen for example   429: 120
# Maxlen for example   430: 308
# Maxlen for example   431: 125
# Maxlen for example   432: 214
# Maxlen for example   433: 236
# Maxlen for example   434: 139
# Maxlen for example   435: 126
# Maxlen for example   436: 145
# Maxlen for example   437: 262
# Maxlen for example   438: 324
# Maxlen for example   439: 159
# Maxlen for example   440: 296
# Maxlen for example   441: 125
# Maxlen for example   442: 141
# Maxlen for example   443: 310
# Maxlen for example   444: 142
# Maxlen for example   445: 112
# Maxlen for example   446: 192
# Maxlen for example   447: 183
# Maxlen for example   448: 190
# Maxlen for example   449: 122
# Maxlen for example   450: 204
# Maxlen for example   451: 152
# Maxlen for example   452: 273
# Maxlen for example   453: 241
# Maxlen for example   454: 133
# Maxlen for example   455: 180
# Maxlen for example   456: 290
# Maxlen for example   457: 249
# Maxlen for example   458: 236
# Maxlen for example   459: 160
# Maxlen for example   460: 270
# Maxlen for example   461: 289
# Maxlen for example   462: 130
# Maxlen for example   463: 216
# Maxlen for example   464: 297
# Maxlen for example   465: 242
# Maxlen for example   466: 307
# Maxlen for example   467: 181
# Maxlen for example   468: 130
# Maxlen for example   469: 164
# Maxlen for example   470: 167
# Maxlen for example   471: 126
# Maxlen for example   472: 131
# Maxlen for example   473: 270
# Maxlen for example   474: 181
# Maxlen for example   475: 194
# Maxlen for example   476: 122
# Maxlen for example   477: 183
# Maxlen for example   478: 261
# Maxlen for example   479: 216
# Maxlen for example   480: 352
# Maxlen for example   481: 145
# Maxlen for example   482: 254
# Maxlen for example   483: 164
# Maxlen for example   484: 120
# Maxlen for example   485: 114
# Maxlen for example   486: 248
# Maxlen for example   487: 302
# Maxlen for example   488: 134
# Maxlen for example   489: 122
# Maxlen for example   490: 132
# Maxlen for example   491: 192
# Maxlen for example   492: 163
# Maxlen for example   493: 118
# Maxlen for example   494: 130
# Maxlen for example   495: 142
# Maxlen for example   496: 201
# Maxlen for example   497: 149
# Maxlen for example   498: 114
# Maxlen for example   499: 143
# Maxlen for example   500: 144
# Maxlen for example   501: 237
# Maxlen for example   502: 277
# Maxlen for example   503: 309
# Maxlen for example   504: 247
# Maxlen for example   505: 153
# Maxlen for example   506: 187
# Maxlen for example   507: 183
# Maxlen for example   508: 145
# Maxlen for example   509: 236
# Maxlen for example   510: 172
# Maxlen for example   511: 323
# Maxlen for example   512: 152
# Maxlen for example   513: 307
# Maxlen for example   514: 144
# Maxlen for example   515: 172
# Maxlen for example   516: 349
# Maxlen for example   517: 277
# Maxlen for example   518: 270
# Maxlen for example   519: 244
# Maxlen for example   520: 263
# Maxlen for example   521: 119
# Maxlen for example   522: 129
# Maxlen for example   523: 190
# Maxlen for example   524: 263
# Maxlen for example   525: 118
# Maxlen for example   526: 174
# Maxlen for example   527: 270
# Maxlen for example   528: 301
# Maxlen for example   529: 147
# Maxlen for example   530: 293
# Maxlen for example   531: 190
# Maxlen for example   532: 148
# Maxlen for example   533: 142
# Maxlen for example   534: 163
# Maxlen for example   535: 201
# Maxlen for example   536: 166
# Maxlen for example   537: 272
# Maxlen for example   538: 135
# Maxlen for example   539: 162
# Maxlen for example   540: 122
# Maxlen for example   541: 125
# Maxlen for example   542: 128
# Maxlen for example   543: 205
# Maxlen for example   544: 268
# Maxlen for example   545: 178
# Maxlen for example   546: 269
# Maxlen for example   547: 125
# Maxlen for example   548: 178
# Maxlen for example   549: 125
# Maxlen for example   550: 144
# Maxlen for example   551: 116
# Maxlen for example   552: 225
# Maxlen for example   553: 120
# Maxlen for example   554: 224
# Maxlen for example   555: 182
# Maxlen for example   556: 113
# Maxlen for example   557: 139
# Maxlen for example   558: 190
# Maxlen for example   559: 115
# Maxlen for example   560: 132
# Maxlen for example   561: 260
# Maxlen for example   562: 185
# Maxlen for example   563: 243
# Maxlen for example   564: 182
# Maxlen for example   565: 137
# Maxlen for example   566: 213
# Maxlen for example   567: 297
# Maxlen for example   568: 262
# Maxlen for example   569: 193
# Maxlen for example   570: 131
# Maxlen for example   571: 147
# Maxlen for example   572: 118
# Maxlen for example   573: 315
# Maxlen for example   574: 183
# Maxlen for example   575: 199
# Maxlen for example   576: 116
# Maxlen for example   577: 180
# Maxlen for example   578: 175
# Maxlen for example   579: 125
# Maxlen for example   580: 155
# Maxlen for example   581: 157
# Maxlen for example   582: 138
# Maxlen for example   583: 115
# Maxlen for example   584: 131
# Maxlen for example   585: 177
# Maxlen for example   586: 123
# Maxlen for example   587: 291
# Maxlen for example   588: 215
# Maxlen for example   589: 236
# Maxlen for example   590: 116
# Maxlen for example   591: 229
# Maxlen for example   592: 118
# Maxlen for example   593: 308
# Maxlen for example   594: 197
# Maxlen for example   595: 126
# Maxlen for example   596: 194
# Maxlen for example   597: 243
# Maxlen for example   598: 115
# Maxlen for example   599: 253
# Maxlen for example   600: 168
# Maxlen for example   601: 148
# Maxlen for example   602: 124
# Maxlen for example   603: 231
# Maxlen for example   604: 157
# Maxlen for example   605: 153
# Maxlen for example   606: 152
# Maxlen for example   607: 134
# Maxlen for example   608: 214
# Maxlen for example   609: 206
# Maxlen for example   610: 333
# Maxlen for example   611: 199
# Maxlen for example   612: 125
# Maxlen for example   613: 127
# Maxlen for example   614: 120
# Maxlen for example   615: 256
# Maxlen for example   616: 170
# Maxlen for example   617: 297
# Maxlen for example   618: 256
# Maxlen for example   619: 122
# Maxlen for example   620: 131
# Maxlen for example   621: 169
# Maxlen for example   622: 190
# Maxlen for example   623: 165
# Maxlen for example   624: 192
# Maxlen for example   625: 178
# Maxlen for example   626: 344
# Maxlen for example   627: 315
# Maxlen for example   628: 143
# Maxlen for example   629: 242
# Maxlen for example   630: 117
# Maxlen for example   631: 140
# Maxlen for example   632: 138
# Maxlen for example   633: 286
# Maxlen for example   634: 315
# Maxlen for example   635: 152
# Maxlen for example   636: 269
# Maxlen for example   637: 235
# Maxlen for example   638: 122
# Maxlen for example   639: 187
# Maxlen for example   640: 172
# Maxlen for example   641: 172
# Maxlen for example   642: 264
# Maxlen for example   643: 160
# Maxlen for example   644: 216
# Maxlen for example   645: 134
# Maxlen for example   646: 278
# Maxlen for example   647: 247
# Maxlen for example   648: 295
# Maxlen for example   649: 161
# Maxlen for example   650: 255
# Maxlen for example   651: 142
# Maxlen for example   652: 307
# Maxlen for example   653: 147
# Maxlen for example   654: 242
# Maxlen for example   655: 175
# Maxlen for example   656: 126
# Maxlen for example   657: 304
# Maxlen for example   658: 134
# Maxlen for example   659: 282
# Maxlen for example   660: 193
# Maxlen for example   661: 203
# Maxlen for example   662: 320
# Maxlen for example   663: 239
# Maxlen for example   664: 321
# Maxlen for example   665: 182
# Maxlen for example   666: 289
# Maxlen for example   667: 202
# Maxlen for example   668: 129
# Maxlen for example   669: 154
# Maxlen for example   670: 117
# Maxlen for example   671: 294
# Maxlen for example   672: 169
# Maxlen for example   673: 210
# Maxlen for example   674: 202
# Maxlen for example   675: 148
# Maxlen for example   676: 125
# Maxlen for example   677: 178
# Maxlen for example   678: 216
# Maxlen for example   679: 255
# Maxlen for example   680: 135
# Maxlen for example   681: 202
# Maxlen for example   682: 121
# Maxlen for example   683: 187
# Maxlen for example   684: 183
# Maxlen for example   685: 282
# Maxlen for example   686: 126
# Maxlen for example   687: 211
# Maxlen for example   688: 296
# Maxlen for example   689: 195
# Maxlen for example   690: 188
# Maxlen for example   691: 144
# Maxlen for example   692: 190
# Maxlen for example   693: 333
# Maxlen for example   694: 205
# Maxlen for example   695: 205
# Maxlen for example   696: 212
# Maxlen for example   697: 235
# Maxlen for example   698: 133
# Maxlen for example   699: 161
# Maxlen for example   700: 189
# Maxlen for example   701: 345
# Maxlen for example   702: 182
# Maxlen for example   703: 178
# Maxlen for example   704: 168
# Maxlen for example   705: 175
# Maxlen for example   706: 173
# Maxlen for example   707: 137
# Maxlen for example   708: 179
# Maxlen for example   709: 323
# Maxlen for example   710: 266
# Maxlen for example   711: 130
# Maxlen for example   712: 212
# Maxlen for example   713: 145
# Maxlen for example   714: 135
# Maxlen for example   715: 240
# Maxlen for example   716: 182
# Maxlen for example   717: 227
# Maxlen for example   718: 199
# Maxlen for example   719: 192
# Maxlen for example   720: 167
# Maxlen for example   721: 119
# Maxlen for example   722: 148
# Maxlen for example   723: 107
# Maxlen for example   724: 296
# Maxlen for example   725: 116
# Maxlen for example   726: 125
# Maxlen for example   727: 257
# Maxlen for example   728: 126
# Maxlen for example   729: 192
# Maxlen for example   730: 197
# Maxlen for example   731: 146
# Maxlen for example   732: 291
# Maxlen for example   733: 126
# Maxlen for example   734: 119
# Maxlen for example   735: 141
# Maxlen for example   736: 296
# Maxlen for example   737: 172
# Maxlen for example   738: 182
# Maxlen for example   739: 162
# Maxlen for example   740: 151
# Maxlen for example   741: 339
# Maxlen for example   742: 138
# Maxlen for example   743: 119
# Maxlen for example   744: 204
# Maxlen for example   745: 135
# Maxlen for example   746: 175
# Maxlen for example   747: 121
# Maxlen for example   748: 156
# Maxlen for example   749: 249
# Maxlen for example   750: 141
# Maxlen for example   751: 120
# Maxlen for example   752: 245
# Maxlen for example   753: 304
# Maxlen for example   754: 210
# Maxlen for example   755: 128
# Maxlen for example   756: 143
# Maxlen for example   757: 129
# Maxlen for example   758: 223
# Maxlen for example   759: 341
# Maxlen for example   760: 139
# Maxlen for example   761: 298
# Maxlen for example   762: 176
# Maxlen for example   763: 142
# Maxlen for example   764: 143
# Maxlen for example   765: 149
# Maxlen for example   766: 204
# Maxlen for example   767: 129
# Maxlen for example   768: 198
# Maxlen for example   769: 121
# Maxlen for example   770: 183
# Maxlen for example   771: 143
# Maxlen for example   772: 126
# Maxlen for example   773: 262
# Maxlen for example   774: 131
# Maxlen for example   775: 121
# Maxlen for example   776: 141
# Maxlen for example   777: 145
# Maxlen for example   778: 184
# Maxlen for example   779: 181
# Maxlen for example   780: 145
# Maxlen for example   781: 252
# Maxlen for example   782: 272
# Maxlen for example   783: 121
# Maxlen for example   784: 294
# Maxlen for example   785: 191
# Maxlen for example   786: 218
# Maxlen for example   787: 165
# Maxlen for example   788: 181
# Maxlen for example   789: 116
# Maxlen for example   790: 263
# Maxlen for example   791: 129
# Maxlen for example   792: 189
# Maxlen for example   793: 184
# Maxlen for example   794: 122
# Maxlen for example   795: 307
# Maxlen for example   796: 234
# Maxlen for example   797: 136
# Maxlen for example   798: 161
# Maxlen for example   799: 262
# Maxlen for example   800: 160
# Maxlen for example   801: 127
# Maxlen for example   802: 151
# Maxlen for example   803: 115
# Maxlen for example   804: 122
# Maxlen for example   805: 298
# Maxlen for example   806: 134
# Maxlen for example   807: 114
# Maxlen for example   808: 238
# Maxlen for example   809: 145
# Maxlen for example   810: 192
# Maxlen for example   811: 148
# Maxlen for example   812: 136
# Maxlen for example   813: 147
# Maxlen for example   814: 145
# Maxlen for example   815: 116
# Maxlen for example   816: 177
# Maxlen for example   817: 140
# Maxlen for example   818: 132
# Maxlen for example   819: 191
# Maxlen for example   820: 207
# Maxlen for example   821: 194
# Maxlen for example   822: 195
# Maxlen for example   823: 125
# Maxlen for example   824: 119
# Maxlen for example   825: 193
# Maxlen for example   826: 291
# Maxlen for example   827: 311
# Maxlen for example   828: 199
# Maxlen for example   829: 194
# Maxlen for example   830: 130
# Maxlen for example   831: 188
# Maxlen for example   832: 229
# Maxlen for example   833: 123
# Maxlen for example   834: 191
# Maxlen for example   835: 125
# Maxlen for example   836: 149
# Maxlen for example   837: 191
# Maxlen for example   838: 123
# Maxlen for example   839: 130
# Maxlen for example   840: 201
# Maxlen for example   841: 146
# Maxlen for example   842: 310
# Maxlen for example   843: 251
# Maxlen for example   844: 118
# Maxlen for example   845: 191
# Maxlen for example   846: 267
# Maxlen for example   847: 185
# Maxlen for example   848: 173
# Maxlen for example   849: 185
# Maxlen for example   850: 257
# Maxlen for example   851: 128
# Maxlen for example   852: 190
# Maxlen for example   853: 116
# Maxlen for example   854: 169
# Maxlen for example   855: 130
# Maxlen for example   856: 264
# Maxlen for example   857: 205
# Maxlen for example   858: 119
# Maxlen for example   859: 179
# Maxlen for example   860: 121
# Maxlen for example   861: 128
# Maxlen for example   862: 137
# Maxlen for example   863: 112
# Maxlen for example   864: 254
# Maxlen for example   865: 123
# Maxlen for example   866: 129
# Maxlen for example   867: 277
# Maxlen for example   868: 128
# Maxlen for example   869: 173
# Maxlen for example   870: 287
# Maxlen for example   871: 120
# Maxlen for example   872: 220
# Maxlen for example   873: 120
# Maxlen for example   874: 271
# Maxlen for example   875: 288
# Maxlen for example   876: 156
# Maxlen for example   877: 151
# Maxlen for example   878: 154
# Maxlen for example   879: 143
# Maxlen for example   880: 125
# Maxlen for example   881: 175
# Maxlen for example   882: 124
# Maxlen for example   883: 227
# Maxlen for example   884: 220
# Maxlen for example   885: 123
# Maxlen for example   886: 202
# Maxlen for example   887: 371
# Maxlen for example   888: 171
# Maxlen for example   889: 116
# Maxlen for example   890: 129
# Maxlen for example   891: 143
# Maxlen for example   892: 126
# Maxlen for example   893: 118
# Maxlen for example   894: 174
# Maxlen for example   895: 280
# Maxlen for example   896: 214
# Maxlen for example   897: 116
# Maxlen for example   898: 276
# Maxlen for example   899: 196
# Maxlen for example   900: 252
# Maxlen for example   901: 191
# Maxlen for example   902: 220
# Maxlen for example   903: 135
# Maxlen for example   904: 277
# Maxlen for example   905: 192
# Maxlen for example   906: 136
# Maxlen for example   907: 164
# Maxlen for example   908: 154
# Maxlen for example   909: 119
# Maxlen for example   910: 218
# Maxlen for example   911: 174
# Maxlen for example   912: 317
# Maxlen for example   913: 132
# Maxlen for example   914: 166
# Maxlen for example   915: 138
# Maxlen for example   916: 162
# Maxlen for example   917: 185
# Maxlen for example   918: 194
# Maxlen for example   919: 204
# Maxlen for example   920: 122
# Maxlen for example   921: 186
# Maxlen for example   922: 129
# Maxlen for example   923: 115
# Maxlen for example   924: 240
# Maxlen for example   925: 125
# Maxlen for example   926: 212
# Maxlen for example   927: 253
# Maxlen for example   928: 133
# Maxlen for example   929: 190
# Maxlen for example   930: 256
# Maxlen for example   931: 150
# Maxlen for example   932: 143
# Maxlen for example   933: 162
# Maxlen for example   934: 314
# Maxlen for example   935: 154
# Maxlen for example   936: 140
# Maxlen for example   937: 125
# Maxlen for example   938: 117
# Maxlen for example   939: 166
# Maxlen for example   940: 134
# Maxlen for example   941: 142
# Maxlen for example   942: 135
# Maxlen for example   943: 248
# Maxlen for example   944: 121
# Maxlen for example   945: 178
# Maxlen for example   946: 232
# Maxlen for example   947: 180
# Maxlen for example   948: 150
# Maxlen for example   949: 157
# Maxlen for example   950: 163
# Maxlen for example   951: 133
# Maxlen for example   952: 248
# Maxlen for example   953: 153
# Maxlen for example   954: 210
# Maxlen for example   955: 195
# Maxlen for example   956: 128
# Maxlen for example   957: 299
# Maxlen for example   958: 289
# Maxlen for example   959: 165
# Maxlen for example   960: 130
# Maxlen for example   961: 209
# Maxlen for example   962: 132
# Maxlen for example   963: 135
# Maxlen for example   964: 188
# Maxlen for example   965: 358
# Maxlen for example   966: 178
# Maxlen for example   967: 183
# Maxlen for example   968: 230
# Maxlen for example   969: 134
# Maxlen for example   970: 204
# Maxlen for example   971: 325
# Maxlen for example   972: 282
# Maxlen for example   973: 336
# Maxlen for example   974: 116
# Maxlen for example   975: 128
# Maxlen for example   976: 194
# Maxlen for example   977: 168
# Maxlen for example   978: 189
# Maxlen for example   979: 161
# Maxlen for example   980: 191
# Maxlen for example   981: 266
# Maxlen for example   982: 261
# Maxlen for example   983: 287
# Maxlen for example   984: 154
# Maxlen for example   985: 226
# Maxlen for example   986: 116
# Maxlen for example   987: 131
# Maxlen for example   988: 124
# Maxlen for example   989: 122
# Maxlen for example   990: 169
# Maxlen for example   991: 148
# Maxlen for example   992: 292
# Maxlen for example   993: 148
# Maxlen for example   994: 251
# Maxlen for example   995: 287
# Maxlen for example   996: 303
# Maxlen for example   997: 172
# Maxlen for example   998: 155
# Maxlen for example   999: 199
# Maxlen for example  1000: 183
# All maxlen: 371

# %%
def encode_all_data(client_data_list: list[ClientData], tokenizer, max_length=512):
    encoded_data = []
    for cd in client_data_list:
        fields = flatten_fields(cd)
        tokens = tokenizer(fields, return_tensors='pt', padding=True, truncation=True, max_length=max_length)
        encoded_data.append(tokens)
    return encoded_data
